# %%
from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json

url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
parameters = {
  'start':'1',
  'limit':'1000',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': '4290ed6d-b24f-4da6-8841-ddeaab80a187',
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)

# %%
type(data)
# Out:
# dict

# %%
import pandas as pd

# Set Pandas options to display all columns
pd.set_option('display.max_columns', None)

# Set Pandas options to display all rows
pd.set_option('display.max_rows', None)

# %%
import pandas as pd

# Use json_normalize to flatten nested JSON data and create a DataFrame (assuming 'data' is a JSON object)
df = pd.json_normalize(data['data'])

# Add a new column 'timestamp' with the current UTC time
df['timestamp'] = pd.to_datetime('now', utc=True)

# Display the top 15 resulting DataFrame
df.head(15)
# Out:
#        id         name symbol          slug  num_market_pairs  \
# 0       1      Bitcoin    BTC       bitcoin             10616
# 1    1027     Ethereum    ETH      ethereum              8032
# 2     825  Tether USDt   USDT        tether             68039
# 3    1839          BNB    BNB           bnb              1840
# 4      52          XRP    XRP           xrp              1170
# 5    5426       Solana    SOL        solana               559
# 6    3408         USDC   USDC      usd-coin             15519
# 7    2010      Cardano    ADA       cardano              1000
# 8    5805    Avalanche   AVAX     avalanche               594
# 9      74     Dogecoin   DOGE      dogecoin               841
# 10   6636     Polkadot    DOT  polkadot-new               636
# 11   1958         TRON    TRX          tron               885
# 12   3890      Polygon  MATIC       polygon              1154
# 13   1975    Chainlink   LINK     chainlink              1497
# 14  11419      Toncoin    TON       toncoin               178
#
#                   date_added  \
# 0   2010-07-13T00:00:00.000Z
# 1   2015-08-07T00:00:00.000Z
# 2   2015-02-25T00:00:00.000Z
# 3   2017-07-25T00:00:00.000Z
# 4   2013-08-04T00:00:00.000Z
# 5   2020-04-10T00:00:00.000Z
# 6   2018-10-08T00:00:00.000Z
# 7   2017-10-01T00:00:00.000Z
# 8   2020-07-13T00:00:00.000Z
# 9   2013-12-15T00:00:00.000Z
# 10  2020-08-19T00:00:00.000Z
# 11  2017-09-13T00:00:00.000Z
# 12  2019-04-28T00:00:00.000Z
# 13  2017-09-20T00:00:00.000Z
# 14  2021-08-26T13:40:22.000Z
#
#                                                  tags         max_supply  \
# 0   [mineable, pow, sha-256, store-of-value, state...     21000000.00000
# 1   [pos, smart-contracts, ethereum-ecosystem, coi...                NaN
# 2   [payments, stablecoin, asset-backed-stablecoin...                NaN
# 3   [marketplace, centralized-exchange, payments, ...                NaN
# 4   [medium-of-exchange, enterprise-solutions, arr... 100000000000.00000
# 5   [pos, platform, solana-ecosystem, cms-holdings...                NaN
# 6   [medium-of-exchange, stablecoin, asset-backed-...                NaN
# 7   [dpos, pos, platform, research, smart-contract...  45000000000.00000
# 8   [defi, smart-contracts, three-arrows-capital-p...    720000000.00000
# 9   [mineable, pow, scrypt, medium-of-exchange, me...                NaN
# 10  [substrate, polkadot, binance-chain, polkadot-...                NaN
# 11  [media, payments, tron-ecosystem, dwf-labs-por...                NaN
# 12  [pos, platform, enterprise-solutions, zero-kno...  10000000000.00000
# 13  [platform, defi, oracles, smart-contracts, sub...   1000000000.00000
# 14  [pos, ftx-bankruptcy-estate, dwf-labs-portfoli...                NaN
#
#     circulating_supply       total_supply  infinite_supply  platform  \
# 0       19569387.00000     19569387.00000            False       NaN
# 1      120209039.96369    120209039.96369             True       NaN
# 2    90659011200.68228  93609080552.55766             True       NaN
# 3      151696084.80463    151696084.80463            False       NaN
# 4    53957460981.00000  99988170772.00000            False       NaN
# 5      427431500.93744    564702922.98566             True       NaN
# 6    24422837840.55804  24422837840.55804            False       NaN
# 7    35328524672.24700  36439975031.08700            False       NaN
# 8      366217361.78904    434250271.78904            False       NaN
# 9   142225226383.70523 142225226383.70523             True       NaN
# 10    1256122040.08032   1388382541.78867             True       NaN
# 11   88437988286.02530  88438032333.38380             True       NaN
# 12    9547813589.33739  10000000000.00000            False       NaN
# 13     556849970.45279   1000000000.00000            False       NaN
# 14    3454932091.79914   5099529344.25767             True       NaN
#
#     cmc_rank  self_reported_circulating_supply  self_reported_market_cap  \
# 0          1                               NaN                       NaN
# 1          2                               NaN                       NaN
# 2          3                               NaN                       NaN
# 3          4                               NaN                       NaN
# 4          5                               NaN                       NaN
# 5          6                               NaN                       NaN
# 6          7                               NaN                       NaN
# 7          8                               NaN                       NaN
# 8          9                               NaN                       NaN
# 9         10                               NaN                       NaN
# 10        11                               NaN                       NaN
# 11        12                 71659659264.00000          7463151993.46032
# 12        13                               NaN                       NaN
# 13        14                               NaN                       NaN
# 14        15                  3414166606.00000          7412948954.80013
#
#     tvl_ratio              last_updated  quote.USD.price  \
# 0         NaN  2023-12-14T04:12:00.000Z      42770.27748
# 1         NaN  2023-12-14T04:12:00.000Z       2254.32489
# 2         NaN  2023-12-14T04:10:00.000Z          1.00015
# 3         NaN  2023-12-14T04:11:00.000Z        249.01288
# 4         NaN  2023-12-14T04:12:00.000Z          0.62436
# 5         NaN  2023-12-14T04:11:00.000Z         70.32073
# 6         NaN  2023-12-14T04:12:00.000Z          1.00031
# 7         NaN  2023-12-14T04:11:00.000Z          0.65674
# 8         NaN  2023-12-14T04:11:00.000Z         38.89534
# 9         NaN  2023-12-14T04:12:00.000Z          0.09578
# 10        NaN  2023-12-14T04:11:00.000Z          7.43910
# 11        NaN  2023-12-14T04:11:00.000Z          0.10415
# 12        NaN  2023-12-14T04:11:00.000Z          0.87852
# 13        NaN  2023-12-14T04:11:00.000Z         14.78170
# 14        NaN  2023-12-14T04:12:00.000Z          2.17123
#
#     quote.USD.volume_24h  quote.USD.volume_change_24h  \
# 0      25212923855.26321                      0.10940
# 1      11498980674.16286                     -3.17080
# 2      49201399232.68186                     -4.84560
# 3        910965897.38456                    -35.83990
# 4       1475823218.90850                     -0.51480
# 5       2175862073.66881                     -6.23540
# 6       6206085183.53134                     -4.41670
# 7       1986368708.97129                     60.01820
# 8       2359547900.03747                      6.54550
# 9        728089636.31025                    -22.99440
# 10       458992650.08303                    -18.42100
# 11       242446971.85005                     -4.02020
# 12       546972991.42076                    -21.45780
# 13       571917279.56225                    -10.22850
# 14        48475461.12221                     30.29180
#
#     quote.USD.percent_change_1h  quote.USD.percent_change_24h  \
# 0                      -0.04333                       4.77487
# 1                       0.06375                       4.38013
# 2                      -0.04143                       0.03790
# 3                      -0.34586                       1.49421
# 4                      -0.02272                       3.03738
# 5                      -0.22020                       7.30943
# 6                       0.02466                       0.00382
# 7                      -0.77990                      17.95977
# 8                      -0.13597                      10.85012
# 9                      -0.32379                       4.99412
# 10                     -0.72699                       9.53862
# 11                     -0.09610                       1.52691
# 12                     -0.34463                       3.41872
# 13                      0.06046                       4.88067
# 14                     -0.71887                       6.67371
#
#     quote.USD.percent_change_7d  quote.USD.percent_change_30d  \
# 0                      -2.66603                      17.38726
# 1                       0.09465                       9.77378
# 2                       0.01269                      -0.01952
# 3                       6.82423                       2.68084
# 4                      -1.50448                      -5.43798
# 5                      11.33355                      29.91233
# 6                       0.02029                       0.03403
# 7                      47.05212                      82.81647
# 8                      46.98881                     131.71170
# 9                      -1.62901                      27.91302
# 10                     22.60794                      38.38306
# 11                     -0.98737                      -1.82437
# 12                      5.70241                      -3.18843
# 13                     -4.72472                       0.68246
# 14                     -5.35114                      -7.56794
#
#     quote.USD.percent_change_60d  quote.USD.percent_change_90d  \
# 0                       59.06155                      60.48672
# 1                       45.03754                      37.82869
# 2                        0.00667                      -0.01563
# 3                       20.16661                      16.98768
# 4                       28.40758                      25.35242
# 5                      220.35522                     266.82293
# 6                        0.01198                       0.03148
# 7                      165.43826                     158.03553
# 8                      323.64157                     310.96244
# 9                       60.87912                      53.98985
# 10                      99.31217                      81.72329
# 11                      22.55543                      24.28014
# 12                      69.48052                      66.61104
# 13                     101.45473                     138.33021
# 14                      12.15050                      13.44962
#
#     quote.USD.market_cap  quote.USD.market_cap_dominance  \
# 0     836988112149.70911                        52.21800
# 1     270990230827.45422                        16.90650
# 2      90672735207.37390                         5.65690
# 3      37774278614.06852                         2.35500
# 4      33689072452.94657                         2.10180
# 5      30057293089.40000                         1.87520
# 6      24430514983.79220                         1.52310
# 7      23201629593.12237                         1.44750
# 8      14244148269.64939                         0.88870
# 9      13622386965.22029                         0.84990
# 10      9344419376.49012                         0.58260
# 11      9210567777.65130                         0.57460
# 12      8387925978.90250                         0.52330
# 13      8231187171.90822                         0.51350
# 14      7501460295.99115                         0.46800
#
#     quote.USD.fully_diluted_market_cap  quote.USD.tvl  \
# 0                   898175827129.57996            NaN
# 1                   270990230827.45001            NaN
# 2                    93623251142.23000            NaN
# 3                    37774278614.07000            NaN
# 4                    62436356048.72000            NaN
# 5                    39710319027.48000            NaN
# 6                    24430514983.79000            NaN
# 7                    29553267264.25000            NaN
# 8                    28004643755.95000            NaN
# 9                    13622386965.22000            NaN
# 10                   10328318675.66000            NaN
# 11                    9210572365.06000            NaN
# 12                    8785179874.34000            NaN
# 13                   14781696343.12000            NaN
# 14                   11072263039.55000            NaN
#
#       quote.USD.last_updated  platform.id platform.name platform.symbol  \
# 0   2023-12-14T04:12:00.000Z          NaN           NaN             NaN
# 1   2023-12-14T04:12:00.000Z          NaN           NaN             NaN
# 2   2023-12-14T04:10:00.000Z   1027.00000      Ethereum             ETH
# 3   2023-12-14T04:11:00.000Z          NaN           NaN             NaN
# 4   2023-12-14T04:12:00.000Z          NaN           NaN             NaN
# 5   2023-12-14T04:11:00.000Z          NaN           NaN             NaN
# 6   2023-12-14T04:12:00.000Z   1027.00000      Ethereum             ETH
# 7   2023-12-14T04:11:00.000Z          NaN           NaN             NaN
# 8   2023-12-14T04:11:00.000Z          NaN           NaN             NaN
# 9   2023-12-14T04:12:00.000Z          NaN           NaN             NaN
# 10  2023-12-14T04:11:00.000Z          NaN           NaN             NaN
# 11  2023-12-14T04:11:00.000Z          NaN           NaN             NaN
# 12  2023-12-14T04:11:00.000Z          NaN           NaN             NaN
# 13  2023-12-14T04:11:00.000Z   1027.00000      Ethereum             ETH
# 14  2023-12-14T04:12:00.000Z          NaN           NaN             NaN
#
#    platform.slug                      platform.token_address  \
# 0            NaN                                         NaN
# 1            NaN                                         NaN
# 2       ethereum  0xdac17f958d2ee523a2206206994597c13d831ec7
# 3            NaN                                         NaN
# 4            NaN                                         NaN
# 5            NaN                                         NaN
# 6       ethereum  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 7            NaN                                         NaN
# 8            NaN                                         NaN
# 9            NaN                                         NaN
# 10           NaN                                         NaN
# 11           NaN                                         NaN
# 12           NaN                                         NaN
# 13      ethereum  0x514910771af9ca656af840dff83e8264ecf986ca
# 14           NaN                                         NaN
#
#                           timestamp
# 0  2023-12-14 04:50:51.079105+00:00
# 1  2023-12-14 04:50:51.079105+00:00
# 2  2023-12-14 04:50:51.079105+00:00
# 3  2023-12-14 04:50:51.079105+00:00
# 4  2023-12-14 04:50:51.079105+00:00
# 5  2023-12-14 04:50:51.079105+00:00
# 6  2023-12-14 04:50:51.079105+00:00
# 7  2023-12-14 04:50:51.079105+00:00
# 8  2023-12-14 04:50:51.079105+00:00
# 9  2023-12-14 04:50:51.079105+00:00
# 10 2023-12-14 04:50:51.079105+00:00
# 11 2023-12-14 04:50:51.079105+00:00
# 12 2023-12-14 04:50:51.079105+00:00
# 13 2023-12-14 04:50:51.079105+00:00
# 14 2023-12-14 04:50:51.079105+00:00

# %%
import os
from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json
import pandas as pd

# Global DataFrame
# df = pd.DataFrame()

# Function to call API
def api_runner():
    url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
    parameters = {
        'start': '1',
        'limit': '15',
        'convert': 'USD'
    }
    headers = {
        'Accepts': 'application/json',
        'X-CMC_PRO_API_KEY': '4290ed6d-b24f-4da6-8841-ddeaab80a187',
    }

    session = Session()
    session.headers.update(headers)

    try:
        response = session.get(url, params=parameters)
        data = json.loads(response.text)
    except (ConnectionError, Timeout, TooManyRedirects) as e:
        print(e)

        
        # Append DataFrame 2 and pin to the original DataFrame
#         df2 = pd.json_normalize(data['data'])
#         df2['timestamp'] = pd.to_datetime('now', utc=True)
#         df_append = pd.DataFrame(df2)
#         df = pd.concat([df,df_append])
        
        df = pd.json_normalize(data['data'])
        df['timestamp'] = pd.to_datetime('now', utc=True)
        df

        if not os.path.isfile(r'C:\Users\Jordan\Desktop\Projects\Data Analyst\Python\API.csv'):
            df.to_csv(r'C:\Users\Jordan\Desktop\Projects\Data Analyst\Python\API.csv', header='column_names')
        else:
            df.to_csv(r'C:\Users\Jordan\Desktop\Projects\Data Analyst\Python\API.csv', mode='a', header=False)
        
        return data

# %%
# Creating a loop to test the API runner
import os
from time import time
from time import sleep

for i in range(333):
    api_data = api_runner()
    print('API Runner Completed')
    sleep(60)  # Sleep for 1 minute
exit()
# Out:
# API Runner Completed
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[90], line 9
#       7     api_data = api_runner()
#       8     print('API Runner Completed')
# ----> 9     sleep(60)  # Sleep for 1 minute
#      10 exit()
#
# KeyboardInterrupt:

# %%
df72 = pd.read_csv(r'C:\Users\Jordan\Desktop\Projects\Data Analyst\Python\API.csv')
df72
# Out:
#      Unnamed: 0     id         name symbol          slug  num_market_pairs  \
# 0             0      1      Bitcoin    BTC       bitcoin             10616
# 1             1   1027     Ethereum    ETH      ethereum              8011
# 2             2    825  Tether USDt   USDT        tether             67829
# 3             3   1839          BNB    BNB           bnb              1832
# 4             4     52          XRP    XRP           xrp              1170
# 5             5   5426       Solana    SOL        solana               559
# 6             6   3408         USDC   USDC      usd-coin             15426
# 7             7   2010      Cardano    ADA       cardano               997
# 8             8   5805    Avalanche   AVAX     avalanche               585
# 9             9     74     Dogecoin   DOGE      dogecoin               838
# 10           10   1958         TRON    TRX          tron               884
# 11           11   6636     Polkadot    DOT  polkadot-new               635
# 12           12   1975    Chainlink   LINK     chainlink              1488
# 13           13   3890      Polygon  MATIC       polygon              1146
# 14           14  11419      Toncoin    TON       toncoin               176
# 15            0      1      Bitcoin    BTC       bitcoin             10616
# 16            1   1027     Ethereum    ETH      ethereum              8011
# 17            2    825  Tether USDt   USDT        tether             67829
# 18            3   1839          BNB    BNB           bnb              1832
# 19            4     52          XRP    XRP           xrp              1170
# 20            5   5426       Solana    SOL        solana               559
# 21            6   3408         USDC   USDC      usd-coin             15426
# 22            7   2010      Cardano    ADA       cardano               997
# 23            8   5805    Avalanche   AVAX     avalanche               585
# 24            9     74     Dogecoin   DOGE      dogecoin               838
# 25           10   1958         TRON    TRX          tron               884
# 26           11   6636     Polkadot    DOT  polkadot-new               635
# 27           12   1975    Chainlink   LINK     chainlink              1488
# 28           13   3890      Polygon  MATIC       polygon              1146
# 29           14  11419      Toncoin    TON       toncoin               176
# 30            0      1      Bitcoin    BTC       bitcoin             10616
# 31            1   1027     Ethereum    ETH      ethereum              8011
# 32            2    825  Tether USDt   USDT        tether             67829
# 33            3   1839          BNB    BNB           bnb              1832
# 34            4     52          XRP    XRP           xrp              1170
# 35            5   5426       Solana    SOL        solana               559
# 36            6   3408         USDC   USDC      usd-coin             15426
# 37            7   2010      Cardano    ADA       cardano               997
# 38            8   5805    Avalanche   AVAX     avalanche               585
# 39            9     74     Dogecoin   DOGE      dogecoin               838
# 40           10   1958         TRON    TRX          tron               884
# 41           11   6636     Polkadot    DOT  polkadot-new               635
# 42           12   1975    Chainlink   LINK     chainlink              1488
# 43           13   3890      Polygon  MATIC       polygon              1146
# 44           14  11419      Toncoin    TON       toncoin               176
# 45            0      1      Bitcoin    BTC       bitcoin             10616
# 46            1   1027     Ethereum    ETH      ethereum              8011
# 47            2    825  Tether USDt   USDT        tether             67829
# 48            3   1839          BNB    BNB           bnb              1832
# 49            4     52          XRP    XRP           xrp              1170
# 50            5   5426       Solana    SOL        solana               559
# 51            6   3408         USDC   USDC      usd-coin             15426
# 52            7   2010      Cardano    ADA       cardano               997
# 53            8   5805    Avalanche   AVAX     avalanche               585
# 54            9     74     Dogecoin   DOGE      dogecoin               838
# 55           10   1958         TRON    TRX          tron               884
# 56           11   6636     Polkadot    DOT  polkadot-new               635
# 57           12   1975    Chainlink   LINK     chainlink              1488
# 58           13   3890      Polygon  MATIC       polygon              1146
# 59           14  11419      Toncoin    TON       toncoin               176
# 60            0      1      Bitcoin    BTC       bitcoin             10616
# 61            1   1027     Ethereum    ETH      ethereum              8011
# 62            2    825  Tether USDt   USDT        tether             67830
# 63            3   1839          BNB    BNB           bnb              1832
# 64            4     52          XRP    XRP           xrp              1170
# 65            5   5426       Solana    SOL        solana               559
# 66            6   3408         USDC   USDC      usd-coin             15426
# 67            7   2010      Cardano    ADA       cardano               997
# 68            8   5805    Avalanche   AVAX     avalanche               585
# 69            9     74     Dogecoin   DOGE      dogecoin               838
# 70           10   1958         TRON    TRX          tron               884
# 71           11   6636     Polkadot    DOT  polkadot-new               635
# 72           12   1975    Chainlink   LINK     chainlink              1488
# 73           13   3890      Polygon  MATIC       polygon              1146
# 74           14  11419      Toncoin    TON       toncoin               176
# 75            0      1      Bitcoin    BTC       bitcoin             10616
# 76            1   1027     Ethereum    ETH      ethereum              8011
# 77            2    825  Tether USDt   USDT        tether             67830
# 78            3   1839          BNB    BNB           bnb              1832
# 79            4     52          XRP    XRP           xrp              1170
# 80            5   5426       Solana    SOL        solana               559
# 81            6   3408         USDC   USDC      usd-coin             15427
# 82            7   2010      Cardano    ADA       cardano               997
# 83            8   5805    Avalanche   AVAX     avalanche               585
# 84            9     74     Dogecoin   DOGE      dogecoin               838
# 85           10   1958         TRON    TRX          tron               884
# 86           11   6636     Polkadot    DOT  polkadot-new               635
# 87           12   1975    Chainlink   LINK     chainlink              1488
# 88           13   3890      Polygon  MATIC       polygon              1146
# 89           14  11419      Toncoin    TON       toncoin               176
# 90            0      1      Bitcoin    BTC       bitcoin             10616
# 91            1   1027     Ethereum    ETH      ethereum              8011
# 92            2    825  Tether USDt   USDT        tether             67830
# 93            3   1839          BNB    BNB           bnb              1832
# 94            4     52          XRP    XRP           xrp              1170
# 95            5   5426       Solana    SOL        solana               559
# 96            6   3408         USDC   USDC      usd-coin             15427
# 97            7   2010      Cardano    ADA       cardano               997
# 98            8   5805    Avalanche   AVAX     avalanche               585
# 99            9     74     Dogecoin   DOGE      dogecoin               838
# 100          10   1958         TRON    TRX          tron               884
# 101          11   6636     Polkadot    DOT  polkadot-new               635
# 102          12   1975    Chainlink   LINK     chainlink              1488
# 103          13   3890      Polygon  MATIC       polygon              1146
# 104          14  11419      Toncoin    TON       toncoin               176
# 105           0      1      Bitcoin    BTC       bitcoin             10616
# 106           1   1027     Ethereum    ETH      ethereum              8011
# 107           2    825  Tether USDt   USDT        tether             67830
# 108           3   1839          BNB    BNB           bnb              1832
# 109           4     52          XRP    XRP           xrp              1170
# 110           5   5426       Solana    SOL        solana               559
# 111           6   3408         USDC   USDC      usd-coin             15427
# 112           7   2010      Cardano    ADA       cardano               997
# 113           8   5805    Avalanche   AVAX     avalanche               585
# 114           9     74     Dogecoin   DOGE      dogecoin               838
# 115          10   1958         TRON    TRX          tron               884
# 116          11   6636     Polkadot    DOT  polkadot-new               635
# 117          12   1975    Chainlink   LINK     chainlink              1488
# 118          13   3890      Polygon  MATIC       polygon              1146
# 119          14  11419      Toncoin    TON       toncoin               176
# 120           0      1      Bitcoin    BTC       bitcoin             10616
# 121           1   1027     Ethereum    ETH      ethereum              8011
# 122           2    825  Tether USDt   USDT        tether             67830
# 123           3   1839          BNB    BNB           bnb              1832
# 124           4     52          XRP    XRP           xrp              1170
# 125           5   5426       Solana    SOL        solana               559
# 126           6   3408         USDC   USDC      usd-coin             15427
# 127           7   2010      Cardano    ADA       cardano               997
# 128           8   5805    Avalanche   AVAX     avalanche               585
# 129           9     74     Dogecoin   DOGE      dogecoin               838
# 130          10   1958         TRON    TRX          tron               884
# 131          11   6636     Polkadot    DOT  polkadot-new               635
# 132          12   1975    Chainlink   LINK     chainlink              1488
# 133          13   3890      Polygon  MATIC       polygon              1146
# 134          14  11419      Toncoin    TON       toncoin               176
# 135           0      1      Bitcoin    BTC       bitcoin             10616
# 136           1   1027     Ethereum    ETH      ethereum              8011
# 137           2    825  Tether USDt   USDT        tether             67830
# 138           3   1839          BNB    BNB           bnb              1832
# 139           4     52          XRP    XRP           xrp              1170
# 140           5   5426       Solana    SOL        solana               559
# 141           6   3408         USDC   USDC      usd-coin             15427
# 142           7   2010      Cardano    ADA       cardano               997
# 143           8   5805    Avalanche   AVAX     avalanche               585
# 144           9     74     Dogecoin   DOGE      dogecoin               838
# 145          10   1958         TRON    TRX          tron               884
# 146          11   6636     Polkadot    DOT  polkadot-new               635
# 147          12   1975    Chainlink   LINK     chainlink              1488
# 148          13   3890      Polygon  MATIC       polygon              1146
# 149          14  11419      Toncoin    TON       toncoin               176
#
#                    date_added  \
# 0    2010-07-13T00:00:00.000Z
# 1    2015-08-07T00:00:00.000Z
# 2    2015-02-25T00:00:00.000Z
# 3    2017-07-25T00:00:00.000Z
# 4    2013-08-04T00:00:00.000Z
# 5    2020-04-10T00:00:00.000Z
# 6    2018-10-08T00:00:00.000Z
# 7    2017-10-01T00:00:00.000Z
# 8    2020-07-13T00:00:00.000Z
# 9    2013-12-15T00:00:00.000Z
# 10   2017-09-13T00:00:00.000Z
# 11   2020-08-19T00:00:00.000Z
# 12   2017-09-20T00:00:00.000Z
# 13   2019-04-28T00:00:00.000Z
# 14   2021-08-26T13:40:22.000Z
# 15   2010-07-13T00:00:00.000Z
# 16   2015-08-07T00:00:00.000Z
# 17   2015-02-25T00:00:00.000Z
# 18   2017-07-25T00:00:00.000Z
# 19   2013-08-04T00:00:00.000Z
# 20   2020-04-10T00:00:00.000Z
# 21   2018-10-08T00:00:00.000Z
# 22   2017-10-01T00:00:00.000Z
# 23   2020-07-13T00:00:00.000Z
# 24   2013-12-15T00:00:00.000Z
# 25   2017-09-13T00:00:00.000Z
# 26   2020-08-19T00:00:00.000Z
# 27   2017-09-20T00:00:00.000Z
# 28   2019-04-28T00:00:00.000Z
# 29   2021-08-26T13:40:22.000Z
# 30   2010-07-13T00:00:00.000Z
# 31   2015-08-07T00:00:00.000Z
# 32   2015-02-25T00:00:00.000Z
# 33   2017-07-25T00:00:00.000Z
# 34   2013-08-04T00:00:00.000Z
# 35   2020-04-10T00:00:00.000Z
# 36   2018-10-08T00:00:00.000Z
# 37   2017-10-01T00:00:00.000Z
# 38   2020-07-13T00:00:00.000Z
# 39   2013-12-15T00:00:00.000Z
# 40   2017-09-13T00:00:00.000Z
# 41   2020-08-19T00:00:00.000Z
# 42   2017-09-20T00:00:00.000Z
# 43   2019-04-28T00:00:00.000Z
# 44   2021-08-26T13:40:22.000Z
# 45   2010-07-13T00:00:00.000Z
# 46   2015-08-07T00:00:00.000Z
# 47   2015-02-25T00:00:00.000Z
# 48   2017-07-25T00:00:00.000Z
# 49   2013-08-04T00:00:00.000Z
# 50   2020-04-10T00:00:00.000Z
# 51   2018-10-08T00:00:00.000Z
# 52   2017-10-01T00:00:00.000Z
# 53   2020-07-13T00:00:00.000Z
# 54   2013-12-15T00:00:00.000Z
# 55   2017-09-13T00:00:00.000Z
# 56   2020-08-19T00:00:00.000Z
# 57   2017-09-20T00:00:00.000Z
# 58   2019-04-28T00:00:00.000Z
# 59   2021-08-26T13:40:22.000Z
# 60   2010-07-13T00:00:00.000Z
# 61   2015-08-07T00:00:00.000Z
# 62   2015-02-25T00:00:00.000Z
# 63   2017-07-25T00:00:00.000Z
# 64   2013-08-04T00:00:00.000Z
# 65   2020-04-10T00:00:00.000Z
# 66   2018-10-08T00:00:00.000Z
# 67   2017-10-01T00:00:00.000Z
# 68   2020-07-13T00:00:00.000Z
# 69   2013-12-15T00:00:00.000Z
# 70   2017-09-13T00:00:00.000Z
# 71   2020-08-19T00:00:00.000Z
# 72   2017-09-20T00:00:00.000Z
# 73   2019-04-28T00:00:00.000Z
# 74   2021-08-26T13:40:22.000Z
# 75   2010-07-13T00:00:00.000Z
# 76   2015-08-07T00:00:00.000Z
# 77   2015-02-25T00:00:00.000Z
# 78   2017-07-25T00:00:00.000Z
# 79   2013-08-04T00:00:00.000Z
# 80   2020-04-10T00:00:00.000Z
# 81   2018-10-08T00:00:00.000Z
# 82   2017-10-01T00:00:00.000Z
# 83   2020-07-13T00:00:00.000Z
# 84   2013-12-15T00:00:00.000Z
# 85   2017-09-13T00:00:00.000Z
# 86   2020-08-19T00:00:00.000Z
# 87   2017-09-20T00:00:00.000Z
# 88   2019-04-28T00:00:00.000Z
# 89   2021-08-26T13:40:22.000Z
# 90   2010-07-13T00:00:00.000Z
# 91   2015-08-07T00:00:00.000Z
# 92   2015-02-25T00:00:00.000Z
# 93   2017-07-25T00:00:00.000Z
# 94   2013-08-04T00:00:00.000Z
# 95   2020-04-10T00:00:00.000Z
# 96   2018-10-08T00:00:00.000Z
# 97   2017-10-01T00:00:00.000Z
# 98   2020-07-13T00:00:00.000Z
# 99   2013-12-15T00:00:00.000Z
# 100  2017-09-13T00:00:00.000Z
# 101  2020-08-19T00:00:00.000Z
# 102  2017-09-20T00:00:00.000Z
# 103  2019-04-28T00:00:00.000Z
# 104  2021-08-26T13:40:22.000Z
# 105  2010-07-13T00:00:00.000Z
# 106  2015-08-07T00:00:00.000Z
# 107  2015-02-25T00:00:00.000Z
# 108  2017-07-25T00:00:00.000Z
# 109  2013-08-04T00:00:00.000Z
# 110  2020-04-10T00:00:00.000Z
# 111  2018-10-08T00:00:00.000Z
# 112  2017-10-01T00:00:00.000Z
# 113  2020-07-13T00:00:00.000Z
# 114  2013-12-15T00:00:00.000Z
# 115  2017-09-13T00:00:00.000Z
# 116  2020-08-19T00:00:00.000Z
# 117  2017-09-20T00:00:00.000Z
# 118  2019-04-28T00:00:00.000Z
# 119  2021-08-26T13:40:22.000Z
# 120  2010-07-13T00:00:00.000Z
# 121  2015-08-07T00:00:00.000Z
# 122  2015-02-25T00:00:00.000Z
# 123  2017-07-25T00:00:00.000Z
# 124  2013-08-04T00:00:00.000Z
# 125  2020-04-10T00:00:00.000Z
# 126  2018-10-08T00:00:00.000Z
# 127  2017-10-01T00:00:00.000Z
# 128  2020-07-13T00:00:00.000Z
# 129  2013-12-15T00:00:00.000Z
# 130  2017-09-13T00:00:00.000Z
# 131  2020-08-19T00:00:00.000Z
# 132  2017-09-20T00:00:00.000Z
# 133  2019-04-28T00:00:00.000Z
# 134  2021-08-26T13:40:22.000Z
# 135  2010-07-13T00:00:00.000Z
# 136  2015-08-07T00:00:00.000Z
# 137  2015-02-25T00:00:00.000Z
# 138  2017-07-25T00:00:00.000Z
# 139  2013-08-04T00:00:00.000Z
# 140  2020-04-10T00:00:00.000Z
# 141  2018-10-08T00:00:00.000Z
# 142  2017-10-01T00:00:00.000Z
# 143  2020-07-13T00:00:00.000Z
# 144  2013-12-15T00:00:00.000Z
# 145  2017-09-13T00:00:00.000Z
# 146  2020-08-19T00:00:00.000Z
# 147  2017-09-20T00:00:00.000Z
# 148  2019-04-28T00:00:00.000Z
# 149  2021-08-26T13:40:22.000Z
#
#                                                   tags          max_supply  \
# 0    ['mineable', 'pow', 'sha-256', 'store-of-value...     21000000.000000
# 1    ['pos', 'smart-contracts', 'ethereum-ecosystem...                 NaN
# 2    ['payments', 'stablecoin', 'asset-backed-stabl...                 NaN
# 3    ['marketplace', 'centralized-exchange', 'payme...                 NaN
# 4    ['medium-of-exchange', 'enterprise-solutions',... 100000000000.000000
# 5    ['pos', 'platform', 'solana-ecosystem', 'cms-h...                 NaN
# 6    ['medium-of-exchange', 'stablecoin', 'asset-ba...                 NaN
# 7    ['dpos', 'pos', 'platform', 'research', 'smart...  45000000000.000000
# 8    ['defi', 'smart-contracts', 'three-arrows-capi...    720000000.000000
# 9    ['mineable', 'pow', 'scrypt', 'medium-of-excha...                 NaN
# 10   ['media', 'payments', 'tron-ecosystem', 'dwf-l...                 NaN
# 11   ['substrate', 'polkadot', 'binance-chain', 'po...                 NaN
# 12   ['platform', 'defi', 'oracles', 'smart-contrac...   1000000000.000000
# 13   ['pos', 'platform', 'enterprise-solutions', 'z...  10000000000.000000
# 14   ['pos', 'ftx-bankruptcy-estate', 'dwf-labs-por...                 NaN
# 15   ['mineable', 'pow', 'sha-256', 'store-of-value...     21000000.000000
# 16   ['pos', 'smart-contracts', 'ethereum-ecosystem...                 NaN
# 17   ['payments', 'stablecoin', 'asset-backed-stabl...                 NaN
# 18   ['marketplace', 'centralized-exchange', 'payme...                 NaN
# 19   ['medium-of-exchange', 'enterprise-solutions',... 100000000000.000000
# 20   ['pos', 'platform', 'solana-ecosystem', 'cms-h...                 NaN
# 21   ['medium-of-exchange', 'stablecoin', 'asset-ba...                 NaN
# 22   ['dpos', 'pos', 'platform', 'research', 'smart...  45000000000.000000
# 23   ['defi', 'smart-contracts', 'three-arrows-capi...    720000000.000000
# 24   ['mineable', 'pow', 'scrypt', 'medium-of-excha...                 NaN
# 25   ['media', 'payments', 'tron-ecosystem', 'dwf-l...                 NaN
# 26   ['substrate', 'polkadot', 'binance-chain', 'po...                 NaN
# 27   ['platform', 'defi', 'oracles', 'smart-contrac...   1000000000.000000
# 28   ['pos', 'platform', 'enterprise-solutions', 'z...  10000000000.000000
# 29   ['pos', 'ftx-bankruptcy-estate', 'dwf-labs-por...                 NaN
# 30   ['mineable', 'pow', 'sha-256', 'store-of-value...     21000000.000000
# 31   ['pos', 'smart-contracts', 'ethereum-ecosystem...                 NaN
# 32   ['payments', 'stablecoin', 'asset-backed-stabl...                 NaN
# 33   ['marketplace', 'centralized-exchange', 'payme...                 NaN
# 34   ['medium-of-exchange', 'enterprise-solutions',... 100000000000.000000
# 35   ['pos', 'platform', 'solana-ecosystem', 'cms-h...                 NaN
# 36   ['medium-of-exchange', 'stablecoin', 'asset-ba...                 NaN
# 37   ['dpos', 'pos', 'platform', 'research', 'smart...  45000000000.000000
# 38   ['defi', 'smart-contracts', 'three-arrows-capi...    720000000.000000
# 39   ['mineable', 'pow', 'scrypt', 'medium-of-excha...                 NaN
# 40   ['media', 'payments', 'tron-ecosystem', 'dwf-l...                 NaN
# 41   ['substrate', 'polkadot', 'binance-chain', 'po...                 NaN
# 42   ['platform', 'defi', 'oracles', 'smart-contrac...   1000000000.000000
# 43   ['pos', 'platform', 'enterprise-solutions', 'z...  10000000000.000000
# 44   ['pos', 'ftx-bankruptcy-estate', 'dwf-labs-por...                 NaN
# 45   ['mineable', 'pow', 'sha-256', 'store-of-value...     21000000.000000
# 46   ['pos', 'smart-contracts', 'ethereum-ecosystem...                 NaN
# 47   ['payments', 'stablecoin', 'asset-backed-stabl...                 NaN
# 48   ['marketplace', 'centralized-exchange', 'payme...                 NaN
# 49   ['medium-of-exchange', 'enterprise-solutions',... 100000000000.000000
# 50   ['pos', 'platform', 'solana-ecosystem', 'cms-h...                 NaN
# 51   ['medium-of-exchange', 'stablecoin', 'asset-ba...                 NaN
# 52   ['dpos', 'pos', 'platform', 'research', 'smart...  45000000000.000000
# 53   ['defi', 'smart-contracts', 'three-arrows-capi...    720000000.000000
# 54   ['mineable', 'pow', 'scrypt', 'medium-of-excha...                 NaN
# 55   ['media', 'payments', 'tron-ecosystem', 'dwf-l...                 NaN
# 56   ['substrate', 'polkadot', 'binance-chain', 'po...                 NaN
# 57   ['platform', 'defi', 'oracles', 'smart-contrac...   1000000000.000000
# 58   ['pos', 'platform', 'enterprise-solutions', 'z...  10000000000.000000
# 59   ['pos', 'ftx-bankruptcy-estate', 'dwf-labs-por...                 NaN
# 60   ['mineable', 'pow', 'sha-256', 'store-of-value...     21000000.000000
# 61   ['pos', 'smart-contracts', 'ethereum-ecosystem...                 NaN
# 62   ['payments', 'stablecoin', 'asset-backed-stabl...                 NaN
# 63   ['marketplace', 'centralized-exchange', 'payme...                 NaN
# 64   ['medium-of-exchange', 'enterprise-solutions',... 100000000000.000000
# 65   ['pos', 'platform', 'solana-ecosystem', 'cms-h...                 NaN
# 66   ['medium-of-exchange', 'stablecoin', 'asset-ba...                 NaN
# 67   ['dpos', 'pos', 'platform', 'research', 'smart...  45000000000.000000
# 68   ['defi', 'smart-contracts', 'three-arrows-capi...    720000000.000000
# 69   ['mineable', 'pow', 'scrypt', 'medium-of-excha...                 NaN
# 70   ['media', 'payments', 'tron-ecosystem', 'dwf-l...                 NaN
# 71   ['substrate', 'polkadot', 'binance-chain', 'po...                 NaN
# 72   ['platform', 'defi', 'oracles', 'smart-contrac...   1000000000.000000
# 73   ['pos', 'platform', 'enterprise-solutions', 'z...  10000000000.000000
# 74   ['pos', 'ftx-bankruptcy-estate', 'dwf-labs-por...                 NaN
# 75   ['mineable', 'pow', 'sha-256', 'store-of-value...     21000000.000000
# 76   ['pos', 'smart-contracts', 'ethereum-ecosystem...                 NaN
# 77   ['payments', 'stablecoin', 'asset-backed-stabl...                 NaN
# 78   ['marketplace', 'centralized-exchange', 'payme...                 NaN
# 79   ['medium-of-exchange', 'enterprise-solutions',... 100000000000.000000
# 80   ['pos', 'platform', 'solana-ecosystem', 'cms-h...                 NaN
# 81   ['medium-of-exchange', 'stablecoin', 'asset-ba...                 NaN
# 82   ['dpos', 'pos', 'platform', 'research', 'smart...  45000000000.000000
# 83   ['defi', 'smart-contracts', 'three-arrows-capi...    720000000.000000
# 84   ['mineable', 'pow', 'scrypt', 'medium-of-excha...                 NaN
# 85   ['media', 'payments', 'tron-ecosystem', 'dwf-l...                 NaN
# 86   ['substrate', 'polkadot', 'binance-chain', 'po...                 NaN
# 87   ['platform', 'defi', 'oracles', 'smart-contrac...   1000000000.000000
# 88   ['pos', 'platform', 'enterprise-solutions', 'z...  10000000000.000000
# 89   ['pos', 'ftx-bankruptcy-estate', 'dwf-labs-por...                 NaN
# 90   ['mineable', 'pow', 'sha-256', 'store-of-value...     21000000.000000
# 91   ['pos', 'smart-contracts', 'ethereum-ecosystem...                 NaN
# 92   ['payments', 'stablecoin', 'asset-backed-stabl...                 NaN
# 93   ['marketplace', 'centralized-exchange', 'payme...                 NaN
# 94   ['medium-of-exchange', 'enterprise-solutions',... 100000000000.000000
# 95   ['pos', 'platform', 'solana-ecosystem', 'cms-h...                 NaN
# 96   ['medium-of-exchange', 'stablecoin', 'asset-ba...                 NaN
# 97   ['dpos', 'pos', 'platform', 'research', 'smart...  45000000000.000000
# 98   ['defi', 'smart-contracts', 'three-arrows-capi...    720000000.000000
# 99   ['mineable', 'pow', 'scrypt', 'medium-of-excha...                 NaN
# 100  ['media', 'payments', 'tron-ecosystem', 'dwf-l...                 NaN
# 101  ['substrate', 'polkadot', 'binance-chain', 'po...                 NaN
# 102  ['platform', 'defi', 'oracles', 'smart-contrac...   1000000000.000000
# 103  ['pos', 'platform', 'enterprise-solutions', 'z...  10000000000.000000
# 104  ['pos', 'ftx-bankruptcy-estate', 'dwf-labs-por...                 NaN
# 105  ['mineable', 'pow', 'sha-256', 'store-of-value...     21000000.000000
# 106  ['pos', 'smart-contracts', 'ethereum-ecosystem...                 NaN
# 107  ['payments', 'stablecoin', 'asset-backed-stabl...                 NaN
# 108  ['marketplace', 'centralized-exchange', 'payme...                 NaN
# 109  ['medium-of-exchange', 'enterprise-solutions',... 100000000000.000000
# 110  ['pos', 'platform', 'solana-ecosystem', 'cms-h...                 NaN
# 111  ['medium-of-exchange', 'stablecoin', 'asset-ba...                 NaN
# 112  ['dpos', 'pos', 'platform', 'research', 'smart...  45000000000.000000
# 113  ['defi', 'smart-contracts', 'three-arrows-capi...    720000000.000000
# 114  ['mineable', 'pow', 'scrypt', 'medium-of-excha...                 NaN
# 115  ['media', 'payments', 'tron-ecosystem', 'dwf-l...                 NaN
# 116  ['substrate', 'polkadot', 'binance-chain', 'po...                 NaN
# 117  ['platform', 'defi', 'oracles', 'smart-contrac...   1000000000.000000
# 118  ['pos', 'platform', 'enterprise-solutions', 'z...  10000000000.000000
# 119  ['pos', 'ftx-bankruptcy-estate', 'dwf-labs-por...                 NaN
# 120  ['mineable', 'pow', 'sha-256', 'store-of-value...     21000000.000000
# 121  ['pos', 'smart-contracts', 'ethereum-ecosystem...                 NaN
# 122  ['payments', 'stablecoin', 'asset-backed-stabl...                 NaN
# 123  ['marketplace', 'centralized-exchange', 'payme...                 NaN
# 124  ['medium-of-exchange', 'enterprise-solutions',... 100000000000.000000
# 125  ['pos', 'platform', 'solana-ecosystem', 'cms-h...                 NaN
# 126  ['medium-of-exchange', 'stablecoin', 'asset-ba...                 NaN
# 127  ['dpos', 'pos', 'platform', 'research', 'smart...  45000000000.000000
# 128  ['defi', 'smart-contracts', 'three-arrows-capi...    720000000.000000
# 129  ['mineable', 'pow', 'scrypt', 'medium-of-excha...                 NaN
# 130  ['media', 'payments', 'tron-ecosystem', 'dwf-l...                 NaN
# 131  ['substrate', 'polkadot', 'binance-chain', 'po...                 NaN
# 132  ['platform', 'defi', 'oracles', 'smart-contrac...   1000000000.000000
# 133  ['pos', 'platform', 'enterprise-solutions', 'z...  10000000000.000000
# 134  ['pos', 'ftx-bankruptcy-estate', 'dwf-labs-por...                 NaN
# 135  ['mineable', 'pow', 'sha-256', 'store-of-value...     21000000.000000
# 136  ['pos', 'smart-contracts', 'ethereum-ecosystem...                 NaN
# 137  ['payments', 'stablecoin', 'asset-backed-stabl...                 NaN
# 138  ['marketplace', 'centralized-exchange', 'payme...                 NaN
# 139  ['medium-of-exchange', 'enterprise-solutions',... 100000000000.000000
# 140  ['pos', 'platform', 'solana-ecosystem', 'cms-h...                 NaN
# 141  ['medium-of-exchange', 'stablecoin', 'asset-ba...                 NaN
# 142  ['dpos', 'pos', 'platform', 'research', 'smart...  45000000000.000000
# 143  ['defi', 'smart-contracts', 'three-arrows-capi...    720000000.000000
# 144  ['mineable', 'pow', 'scrypt', 'medium-of-excha...                 NaN
# 145  ['media', 'payments', 'tron-ecosystem', 'dwf-l...                 NaN
# 146  ['substrate', 'polkadot', 'binance-chain', 'po...                 NaN
# 147  ['platform', 'defi', 'oracles', 'smart-contrac...   1000000000.000000
# 148  ['pos', 'platform', 'enterprise-solutions', 'z...  10000000000.000000
# 149  ['pos', 'ftx-bankruptcy-estate', 'dwf-labs-por...                 NaN
#
#      circulating_supply        total_supply  infinite_supply  platform  \
# 0       19567187.000000     19567187.000000            False       NaN
# 1      120215621.816134    120215621.816134             True       NaN
# 2    90545444292.787476  92609080553.052856             True       NaN
# 3      151696535.530012    151696535.530012            False       NaN
# 4    53957460767.000000  99988170772.000000            False       NaN
# 5      426247064.829780    564531619.804407             True       NaN
# 6    24281909013.284336  24281909013.284336            False       NaN
# 7    35327686064.836998  36424942625.351997            False       NaN
# 8      365754203.141695    433787113.141695            False       NaN
# 9   142193786383.705200 142193786383.705200             True       NaN
# 10   88453288711.598221  88453318950.195206             True       NaN
# 11    1255478148.147358   1387738649.855710             True       NaN
# 12     556849970.452787   1000000000.000000            False       NaN
# 13    9547835719.203983  10000000000.000000            False       NaN
# 14    2819067291.071220   5099455389.648839             True       NaN
# 15      19567187.000000     19567187.000000            False       NaN
# 16     120215621.816134    120215621.816134             True       NaN
# 17   90545444292.787476  92609080553.052856             True       NaN
# 18     151696535.530012    151696535.530012            False       NaN
# 19   53957460767.000000  99988170772.000000            False       NaN
# 20     426247064.829780    564531619.804407             True       NaN
# 21   24281909013.284336  24281909013.284336            False       NaN
# 22   35327686064.836998  36424942625.351997            False       NaN
# 23     365754203.141695    433787113.141695            False       NaN
# 24  142193786383.705200 142193786383.705200             True       NaN
# 25   88453288711.598221  88453318950.195206             True       NaN
# 26    1255478148.147358   1387738649.855710             True       NaN
# 27     556849970.452787   1000000000.000000            False       NaN
# 28    9547835719.203983  10000000000.000000            False       NaN
# 29    2819067291.071220   5099455389.648839             True       NaN
# 30      19567187.000000     19567187.000000            False       NaN
# 31     120215621.816134    120215621.816134             True       NaN
# 32   90545444292.787476  92609080553.052856             True       NaN
# 33     151696535.530012    151696535.530012            False       NaN
# 34   53957460767.000000  99988170772.000000            False       NaN
# 35     426247064.829780    564531619.804407             True       NaN
# 36   24281909013.284336  24281909013.284336            False       NaN
# 37   35327686064.836998  36424942625.351997            False       NaN
# 38     365754203.141695    433787113.141695            False       NaN
# 39  142193786383.705200 142193786383.705200             True       NaN
# 40   88453288711.598221  88453318950.195206             True       NaN
# 41    1255478148.147358   1387738649.855710             True       NaN
# 42     556849970.452787   1000000000.000000            False       NaN
# 43    9547835719.203983  10000000000.000000            False       NaN
# 44    2819067291.071220   5099455389.648839             True       NaN
# 45      19567256.000000     19567256.000000            False       NaN
# 46     120215621.816134    120215621.816134             True       NaN
# 47   90545444292.787476  92609080553.052856             True       NaN
# 48     151696524.037180    151696524.037180            False       NaN
# 49   53957460767.000000  99988170772.000000            False       NaN
# 50     426246977.537394    564531532.508454             True       NaN
# 51   24170142513.700359  24170142513.700359            False       NaN
# 52   35327699156.515999  36424942625.351997            False       NaN
# 53     365754486.264889    433787396.264889            False       NaN
# 54  142194876383.705200 142194876383.705200             True       NaN
# 55   88453015725.301254  88453024200.215469             True       NaN
# 56    1255478147.349334   1387738649.057685             True       NaN
# 57     556849970.452787   1000000000.000000            False       NaN
# 58    9547835719.203983  10000000000.000000            False       NaN
# 59    2819067291.071220   5099455389.648839             True       NaN
# 60      19567256.000000     19567256.000000            False       NaN
# 61     120215621.816134    120215621.816134             True       NaN
# 62   90545444292.787476  92609080553.052856             True       NaN
# 63     151696524.037180    151696524.037180            False       NaN
# 64   53957460767.000000  99988170772.000000            False       NaN
# 65     426246977.537394    564531532.508454             True       NaN
# 66   24170142513.700359  24170142513.700359            False       NaN
# 67   35327699156.515999  36424942625.351997            False       NaN
# 68     365754486.264889    433787396.264889            False       NaN
# 69  142194876383.705200 142194876383.705200             True       NaN
# 70   88453015725.301254  88453024200.215469             True       NaN
# 71    1255478147.349334   1387738649.057685             True       NaN
# 72     556849970.452787   1000000000.000000            False       NaN
# 73    9547835719.203983  10000000000.000000            False       NaN
# 74    2819067291.071220   5099455389.648839             True       NaN
# 75      19567256.000000     19567256.000000            False       NaN
# 76     120215621.816134    120215621.816134             True       NaN
# 77   90545444292.787476  92609080553.052856             True       NaN
# 78     151696524.037180    151696524.037180            False       NaN
# 79   53957460767.000000  99988170772.000000            False       NaN
# 80     426246977.537394    564531532.508454             True       NaN
# 81   24170142513.700359  24170142513.700359            False       NaN
# 82   35327699156.515999  36424942625.351997            False       NaN
# 83     365754486.264889    433787396.264889            False       NaN
# 84  142194876383.705200 142194876383.705200             True       NaN
# 85   88453015725.301254  88453024200.215469             True       NaN
# 86    1255478147.349334   1387738649.057685             True       NaN
# 87     556849970.452787   1000000000.000000            False       NaN
# 88    9547835719.203983  10000000000.000000            False       NaN
# 89    2819067291.071220   5099455389.648839             True       NaN
# 90      19567256.000000     19567256.000000            False       NaN
# 91     120215621.816134    120215621.816134             True       NaN
# 92   90545444292.787476  92609080553.052856             True       NaN
# 93     151696524.037180    151696524.037180            False       NaN
# 94   53957460767.000000  99988170772.000000            False       NaN
# 95     426246977.537394    564531532.508454             True       NaN
# 96   24170142513.700359  24170142513.700359            False       NaN
# 97   35327699156.515999  36424942625.351997            False       NaN
# 98     365754486.264889    433787396.264889            False       NaN
# 99  142194876383.705200 142194876383.705200             True       NaN
# 100  88453015725.301254  88453024200.215469             True       NaN
# 101   1255478147.349334   1387738649.057685             True       NaN
# 102    556849970.452787   1000000000.000000            False       NaN
# 103   9547835719.203983  10000000000.000000            False       NaN
# 104   2819067291.071220   5099455389.648839             True       NaN
# 105     19567256.000000     19567256.000000            False       NaN
# 106    120215621.816134    120215621.816134             True       NaN
# 107  90545444292.787476  92609080553.052856             True       NaN
# 108    151696524.037180    151696524.037180            False       NaN
# 109  53957460767.000000  99988170772.000000            False       NaN
# 110    426246977.537394    564531532.508454             True       NaN
# 111  24170142513.700359  24170142513.700359            False       NaN
# 112  35327699156.515999  36424942625.351997            False       NaN
# 113    365754486.264889    433787396.264889            False       NaN
# 114 142194876383.705200 142194876383.705200             True       NaN
# 115  88453015725.301254  88453024200.215469             True       NaN
# 116   1255478147.349334   1387738649.057685             True       NaN
# 117    556849970.452787   1000000000.000000            False       NaN
# 118   9547835719.203983  10000000000.000000            False       NaN
# 119   2819067291.071220   5099455389.648839             True       NaN
# 120     19567256.000000     19567256.000000            False       NaN
# 121    120215621.816134    120215621.816134             True       NaN
# 122  90545444292.787476  92609080553.052856             True       NaN
# 123    151696524.037180    151696524.037180            False       NaN
# 124  53957460767.000000  99988170772.000000            False       NaN
# 125    426246977.537394    564531532.508454             True       NaN
# 126  24170142513.700359  24170142513.700359            False       NaN
# 127  35327699156.515999  36424942625.351997            False       NaN
# 128    365754486.264889    433787396.264889            False       NaN
# 129 142194876383.705200 142194876383.705200             True       NaN
# 130  88453015725.301254  88453024200.215469             True       NaN
# 131   1255478147.349334   1387738649.057685             True       NaN
# 132    556849970.452787   1000000000.000000            False       NaN
# 133   9547835719.203983  10000000000.000000            False       NaN
# 134   2819067291.071220   5099455389.648839             True       NaN
# 135     19567256.000000     19567256.000000            False       NaN
# 136    120215621.816134    120215621.816134             True       NaN
# 137  90545444292.787476  92609080553.052856             True       NaN
# 138    151696524.037180    151696524.037180            False       NaN
# 139  53957460767.000000  99988170772.000000            False       NaN
# 140    426246977.537394    564531532.508454             True       NaN
# 141  24170142513.700359  24170142513.700359            False       NaN
# 142  35327699156.515999  36424942625.351997            False       NaN
# 143    365754486.264889    433787396.264889            False       NaN
# 144 142194876383.705200 142194876383.705200             True       NaN
# 145  88453015725.301254  88453024200.215469             True       NaN
# 146   1255478147.349334   1387738649.057685             True       NaN
# 147    556849970.452787   1000000000.000000            False       NaN
# 148   9547835719.203983  10000000000.000000            False       NaN
# 149   2819067291.071220   5099455389.648839             True       NaN
#
#      cmc_rank  self_reported_circulating_supply  self_reported_market_cap  \
# 0           1                               NaN                       NaN
# 1           2                               NaN                       NaN
# 2           3                               NaN                       NaN
# 3           4                               NaN                       NaN
# 4           5                               NaN                       NaN
# 5           6                               NaN                       NaN
# 6           7                               NaN                       NaN
# 7           8                               NaN                       NaN
# 8           9                               NaN                       NaN
# 9          10                               NaN                       NaN
# 10         11                71659659264.000000         7423178772.195814
# 11         12                               NaN                       NaN
# 12         13                               NaN                       NaN
# 13         14                               NaN                       NaN
# 14         15                 3414166606.000000         7323862854.251374
# 15          1                               NaN                       NaN
# 16          2                               NaN                       NaN
# 17          3                               NaN                       NaN
# 18          4                               NaN                       NaN
# 19          5                               NaN                       NaN
# 20          6                               NaN                       NaN
# 21          7                               NaN                       NaN
# 22          8                               NaN                       NaN
# 23          9                               NaN                       NaN
# 24         10                               NaN                       NaN
# 25         11                71659659264.000000         7422579581.465652
# 26         12                               NaN                       NaN
# 27         13                               NaN                       NaN
# 28         14                               NaN                       NaN
# 29         15                 3414166606.000000         7319275170.846187
# 30          1                               NaN                       NaN
# 31          2                               NaN                       NaN
# 32          3                               NaN                       NaN
# 33          4                               NaN                       NaN
# 34          5                               NaN                       NaN
# 35          6                               NaN                       NaN
# 36          7                               NaN                       NaN
# 37          8                               NaN                       NaN
# 38          9                               NaN                       NaN
# 39         10                               NaN                       NaN
# 40         11                71659659264.000000         7422579581.465652
# 41         12                               NaN                       NaN
# 42         13                               NaN                       NaN
# 43         14                               NaN                       NaN
# 44         15                 3414166606.000000         7319275170.846187
# 45          1                               NaN                       NaN
# 46          2                               NaN                       NaN
# 47          3                               NaN                       NaN
# 48          4                               NaN                       NaN
# 49          5                               NaN                       NaN
# 50          6                               NaN                       NaN
# 51          7                               NaN                       NaN
# 52          8                               NaN                       NaN
# 53          9                               NaN                       NaN
# 54         10                               NaN                       NaN
# 55         11                71659659264.000000         7418614997.145888
# 56         12                               NaN                       NaN
# 57         13                               NaN                       NaN
# 58         14                               NaN                       NaN
# 59         15                 3414166606.000000         7318746602.756624
# 60          1                               NaN                       NaN
# 61          2                               NaN                       NaN
# 62          3                               NaN                       NaN
# 63          4                               NaN                       NaN
# 64          5                               NaN                       NaN
# 65          6                               NaN                       NaN
# 66          7                               NaN                       NaN
# 67          8                               NaN                       NaN
# 68          9                               NaN                       NaN
# 69         10                               NaN                       NaN
# 70         11                71659659264.000000         7425679321.826261
# 71         12                               NaN                       NaN
# 72         13                               NaN                       NaN
# 73         14                               NaN                       NaN
# 74         15                 3414166606.000000         7318440812.308798
# 75          1                               NaN                       NaN
# 76          2                               NaN                       NaN
# 77          3                               NaN                       NaN
# 78          4                               NaN                       NaN
# 79          5                               NaN                       NaN
# 80          6                               NaN                       NaN
# 81          7                               NaN                       NaN
# 82          8                               NaN                       NaN
# 83          9                               NaN                       NaN
# 84         10                               NaN                       NaN
# 85         11                71659659264.000000         7425256197.705355
# 86         12                               NaN                       NaN
# 87         13                               NaN                       NaN
# 88         14                               NaN                       NaN
# 89         15                 3414166606.000000         7319246595.966263
# 90          1                               NaN                       NaN
# 91          2                               NaN                       NaN
# 92          3                               NaN                       NaN
# 93          4                               NaN                       NaN
# 94          5                               NaN                       NaN
# 95          6                               NaN                       NaN
# 96          7                               NaN                       NaN
# 97          8                               NaN                       NaN
# 98          9                               NaN                       NaN
# 99         10                               NaN                       NaN
# 100        11                71659659264.000000         7425256197.705355
# 101        12                               NaN                       NaN
# 102        13                               NaN                       NaN
# 103        14                               NaN                       NaN
# 104        15                 3414166606.000000         7319246595.966263
# 105         1                               NaN                       NaN
# ...
# 149  2023-12-11T22:38:00.000Z          NaN           NaN             NaN
#
#     platform.slug                      platform.token_address  \
# 0             NaN                                         NaN
# 1             NaN                                         NaN
# 2        ethereum  0xdac17f958d2ee523a2206206994597c13d831ec7
# 3             NaN                                         NaN
# 4             NaN                                         NaN
# 5             NaN                                         NaN
# 6        ethereum  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 7             NaN                                         NaN
# 8             NaN                                         NaN
# 9             NaN                                         NaN
# 10            NaN                                         NaN
# 11            NaN                                         NaN
# 12       ethereum  0x514910771af9ca656af840dff83e8264ecf986ca
# 13            NaN                                         NaN
# 14            NaN                                         NaN
# 15            NaN                                         NaN
# 16            NaN                                         NaN
# 17       ethereum  0xdac17f958d2ee523a2206206994597c13d831ec7
# 18            NaN                                         NaN
# 19            NaN                                         NaN
# 20            NaN                                         NaN
# 21       ethereum  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 22            NaN                                         NaN
# 23            NaN                                         NaN
# 24            NaN                                         NaN
# 25            NaN                                         NaN
# 26            NaN                                         NaN
# 27       ethereum  0x514910771af9ca656af840dff83e8264ecf986ca
# 28            NaN                                         NaN
# 29            NaN                                         NaN
# 30            NaN                                         NaN
# 31            NaN                                         NaN
# 32       ethereum  0xdac17f958d2ee523a2206206994597c13d831ec7
# 33            NaN                                         NaN
# 34            NaN                                         NaN
# 35            NaN                                         NaN
# 36       ethereum  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 37            NaN                                         NaN
# 38            NaN                                         NaN
# 39            NaN                                         NaN
# 40            NaN                                         NaN
# 41            NaN                                         NaN
# 42       ethereum  0x514910771af9ca656af840dff83e8264ecf986ca
# 43            NaN                                         NaN
# 44            NaN                                         NaN
# 45            NaN                                         NaN
# 46            NaN                                         NaN
# 47       ethereum  0xdac17f958d2ee523a2206206994597c13d831ec7
# 48            NaN                                         NaN
# 49            NaN                                         NaN
# 50            NaN                                         NaN
# 51       ethereum  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 52            NaN                                         NaN
# 53            NaN                                         NaN
# 54            NaN                                         NaN
# 55            NaN                                         NaN
# 56            NaN                                         NaN
# 57       ethereum  0x514910771af9ca656af840dff83e8264ecf986ca
# 58            NaN                                         NaN
# 59            NaN                                         NaN
# 60            NaN                                         NaN
# 61            NaN                                         NaN
# 62       ethereum  0xdac17f958d2ee523a2206206994597c13d831ec7
# 63            NaN                                         NaN
# 64            NaN                                         NaN
# 65            NaN                                         NaN
# 66       ethereum  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 67            NaN                                         NaN
# 68            NaN                                         NaN
# 69            NaN                                         NaN
# 70            NaN                                         NaN
# 71            NaN                                         NaN
# 72       ethereum  0x514910771af9ca656af840dff83e8264ecf986ca
# 73            NaN                                         NaN
# 74            NaN                                         NaN
# 75            NaN                                         NaN
# 76            NaN                                         NaN
# 77       ethereum  0xdac17f958d2ee523a2206206994597c13d831ec7
# 78            NaN                                         NaN
# 79            NaN                                         NaN
# 80            NaN                                         NaN
# 81       ethereum  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 82            NaN                                         NaN
# 83            NaN                                         NaN
# 84            NaN                                         NaN
# 85            NaN                                         NaN
# 86            NaN                                         NaN
# 87       ethereum  0x514910771af9ca656af840dff83e8264ecf986ca
# 88            NaN                                         NaN
# 89            NaN                                         NaN
# 90            NaN                                         NaN
# 91            NaN                                         NaN
# 92       ethereum  0xdac17f958d2ee523a2206206994597c13d831ec7
# 93            NaN                                         NaN
# 94            NaN                                         NaN
# 95            NaN                                         NaN
# 96       ethereum  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 97            NaN                                         NaN
# 98            NaN                                         NaN
# 99            NaN                                         NaN
# 100           NaN                                         NaN
# 101           NaN                                         NaN
# 102      ethereum  0x514910771af9ca656af840dff83e8264ecf986ca
# 103           NaN                                         NaN
# 104           NaN                                         NaN
# 105           NaN                                         NaN
# 106           NaN                                         NaN
# 107      ethereum  0xdac17f958d2ee523a2206206994597c13d831ec7
# 108           NaN                                         NaN
# 109           NaN                                         NaN
# 110           NaN                                         NaN
# 111      ethereum  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 112           NaN                                         NaN
# 113           NaN                                         NaN
# 114           NaN                                         NaN
# 115           NaN                                         NaN
# 116           NaN                                         NaN
# 117      ethereum  0x514910771af9ca656af840dff83e8264ecf986ca
# 118           NaN                                         NaN
# 119           NaN                                         NaN
# 120           NaN                                         NaN
# 121           NaN                                         NaN
# 122      ethereum  0xdac17f958d2ee523a2206206994597c13d831ec7
# 123           NaN                                         NaN
# 124           NaN                                         NaN
# 125           NaN                                         NaN
# 126      ethereum  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 127           NaN                                         NaN
# 128           NaN                                         NaN
# 129           NaN                                         NaN
# 130           NaN                                         NaN
# 131           NaN                                         NaN
# 132      ethereum  0x514910771af9ca656af840dff83e8264ecf986ca
# 133           NaN                                         NaN
# 134           NaN                                         NaN
# 135           NaN                                         NaN
# 136           NaN                                         NaN
# 137      ethereum  0xdac17f958d2ee523a2206206994597c13d831ec7
# 138           NaN                                         NaN
# 139           NaN                                         NaN
# 140           NaN                                         NaN
# 141      ethereum  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 142           NaN                                         NaN
# 143           NaN                                         NaN
# 144           NaN                                         NaN
# 145           NaN                                         NaN
# 146           NaN                                         NaN
# 147      ethereum  0x514910771af9ca656af840dff83e8264ecf986ca
# 148           NaN                                         NaN
# 149           NaN                                         NaN
#
#                             timestamp
# 0    2023-12-11 22:09:26.249564+00:00
# 1    2023-12-11 22:09:26.249564+00:00
# 2    2023-12-11 22:09:26.249564+00:00
# 3    2023-12-11 22:09:26.249564+00:00
# 4    2023-12-11 22:09:26.249564+00:00
# 5    2023-12-11 22:09:26.249564+00:00
# 6    2023-12-11 22:09:26.249564+00:00
# 7    2023-12-11 22:09:26.249564+00:00
# 8    2023-12-11 22:09:26.249564+00:00
# 9    2023-12-11 22:09:26.249564+00:00
# 10   2023-12-11 22:09:26.249564+00:00
# 11   2023-12-11 22:09:26.249564+00:00
# 12   2023-12-11 22:09:26.249564+00:00
# 13   2023-12-11 22:09:26.249564+00:00
# 14   2023-12-11 22:09:26.249564+00:00
# 15   2023-12-11 22:10:26.534735+00:00
# 16   2023-12-11 22:10:26.534735+00:00
# 17   2023-12-11 22:10:26.534735+00:00
# 18   2023-12-11 22:10:26.534735+00:00
# 19   2023-12-11 22:10:26.534735+00:00
# 20   2023-12-11 22:10:26.534735+00:00
# 21   2023-12-11 22:10:26.534735+00:00
# 22   2023-12-11 22:10:26.534735+00:00
# 23   2023-12-11 22:10:26.534735+00:00
# 24   2023-12-11 22:10:26.534735+00:00
# 25   2023-12-11 22:10:26.534735+00:00
# 26   2023-12-11 22:10:26.534735+00:00
# 27   2023-12-11 22:10:26.534735+00:00
# 28   2023-12-11 22:10:26.534735+00:00
# 29   2023-12-11 22:10:26.534735+00:00
# 30   2023-12-11 22:11:22.032612+00:00
# 31   2023-12-11 22:11:22.032612+00:00
# 32   2023-12-11 22:11:22.032612+00:00
# 33   2023-12-11 22:11:22.032612+00:00
# 34   2023-12-11 22:11:22.032612+00:00
# 35   2023-12-11 22:11:22.032612+00:00
# 36   2023-12-11 22:11:22.032612+00:00
# 37   2023-12-11 22:11:22.032612+00:00
# 38   2023-12-11 22:11:22.032612+00:00
# 39   2023-12-11 22:11:22.032612+00:00
# 40   2023-12-11 22:11:22.032612+00:00
# 41   2023-12-11 22:11:22.032612+00:00
# 42   2023-12-11 22:11:22.032612+00:00
# 43   2023-12-11 22:11:22.032612+00:00
# 44   2023-12-11 22:11:22.032612+00:00
# 45   2023-12-11 22:13:10.400700+00:00
# 46   2023-12-11 22:13:10.400700+00:00
# 47   2023-12-11 22:13:10.400700+00:00
# 48   2023-12-11 22:13:10.400700+00:00
# 49   2023-12-11 22:13:10.400700+00:00
# 50   2023-12-11 22:13:10.400700+00:00
# 51   2023-12-11 22:13:10.400700+00:00
# 52   2023-12-11 22:13:10.400700+00:00
# 53   2023-12-11 22:13:10.400700+00:00
# 54   2023-12-11 22:13:10.400700+00:00
# 55   2023-12-11 22:13:10.400700+00:00
# 56   2023-12-11 22:13:10.400700+00:00
# 57   2023-12-11 22:13:10.400700+00:00
# 58   2023-12-11 22:13:10.400700+00:00
# 59   2023-12-11 22:13:10.400700+00:00
# 60   2023-12-11 22:27:50.174080+00:00
# 61   2023-12-11 22:27:50.174080+00:00
# 62   2023-12-11 22:27:50.174080+00:00
# 63   2023-12-11 22:27:50.174080+00:00
# 64   2023-12-11 22:27:50.174080+00:00
# 65   2023-12-11 22:27:50.174080+00:00
# 66   2023-12-11 22:27:50.174080+00:00
# 67   2023-12-11 22:27:50.174080+00:00
# 68   2023-12-11 22:27:50.174080+00:00
# 69   2023-12-11 22:27:50.174080+00:00
# 70   2023-12-11 22:27:50.174080+00:00
# 71   2023-12-11 22:27:50.174080+00:00
# 72   2023-12-11 22:27:50.174080+00:00
# 73   2023-12-11 22:27:50.174080+00:00
# 74   2023-12-11 22:27:50.174080+00:00
# 75   2023-12-11 22:36:21.440817+00:00
# 76   2023-12-11 22:36:21.440817+00:00
# 77   2023-12-11 22:36:21.440817+00:00
# 78   2023-12-11 22:36:21.440817+00:00
# 79   2023-12-11 22:36:21.440817+00:00
# 80   2023-12-11 22:36:21.440817+00:00
# 81   2023-12-11 22:36:21.440817+00:00
# 82   2023-12-11 22:36:21.440817+00:00
# 83   2023-12-11 22:36:21.440817+00:00
# 84   2023-12-11 22:36:21.440817+00:00
# 85   2023-12-11 22:36:21.440817+00:00
# 86   2023-12-11 22:36:21.440817+00:00
# 87   2023-12-11 22:36:21.440817+00:00
# 88   2023-12-11 22:36:21.440817+00:00
# 89   2023-12-11 22:36:21.440817+00:00
# 90   2023-12-11 22:36:44.383839+00:00
# 91   2023-12-11 22:36:44.383839+00:00
# 92   2023-12-11 22:36:44.383839+00:00
# 93   2023-12-11 22:36:44.383839+00:00
# 94   2023-12-11 22:36:44.383839+00:00
# 95   2023-12-11 22:36:44.383839+00:00
# 96   2023-12-11 22:36:44.383839+00:00
# 97   2023-12-11 22:36:44.383839+00:00
# 98   2023-12-11 22:36:44.383839+00:00
# 99   2023-12-11 22:36:44.383839+00:00
# 100  2023-12-11 22:36:44.383839+00:00
# 101  2023-12-11 22:36:44.383839+00:00
# 102  2023-12-11 22:36:44.383839+00:00
# 103  2023-12-11 22:36:44.383839+00:00
# 104  2023-12-11 22:36:44.383839+00:00
# 105  2023-12-11 22:37:44.603477+00:00
# 106  2023-12-11 22:37:44.603477+00:00
# 107  2023-12-11 22:37:44.603477+00:00
# 108  2023-12-11 22:37:44.603477+00:00
# 109  2023-12-11 22:37:44.603477+00:00
# 110  2023-12-11 22:37:44.603477+00:00
# 111  2023-12-11 22:37:44.603477+00:00
# 112  2023-12-11 22:37:44.603477+00:00
# 113  2023-12-11 22:37:44.603477+00:00
# 114  2023-12-11 22:37:44.603477+00:00
# 115  2023-12-11 22:37:44.603477+00:00
# 116  2023-12-11 22:37:44.603477+00:00
# 117  2023-12-11 22:37:44.603477+00:00
# 118  2023-12-11 22:37:44.603477+00:00
# 119  2023-12-11 22:37:44.603477+00:00
# 120  2023-12-11 22:37:57.076335+00:00
# 121  2023-12-11 22:37:57.076335+00:00
# 122  2023-12-11 22:37:57.076335+00:00
# 123  2023-12-11 22:37:57.076335+00:00
# 124  2023-12-11 22:37:57.076335+00:00
# 125  2023-12-11 22:37:57.076335+00:00
# 126  2023-12-11 22:37:57.076335+00:00
# 127  2023-12-11 22:37:57.076335+00:00
# 128  2023-12-11 22:37:57.076335+00:00
# 129  2023-12-11 22:37:57.076335+00:00
# 130  2023-12-11 22:37:57.076335+00:00
# 131  2023-12-11 22:37:57.076335+00:00
# 132  2023-12-11 22:37:57.076335+00:00
# 133  2023-12-11 22:37:57.076335+00:00
# 134  2023-12-11 22:37:57.076335+00:00
# 135  2023-12-11 22:39:16.748581+00:00
# 136  2023-12-11 22:39:16.748581+00:00
# 137  2023-12-11 22:39:16.748581+00:00
# 138  2023-12-11 22:39:16.748581+00:00
# 139  2023-12-11 22:39:16.748581+00:00
# 140  2023-12-11 22:39:16.748581+00:00
# 141  2023-12-11 22:39:16.748581+00:00
# 142  2023-12-11 22:39:16.748581+00:00
# 143  2023-12-11 22:39:16.748581+00:00
# 144  2023-12-11 22:39:16.748581+00:00
# 145  2023-12-11 22:39:16.748581+00:00
# 146  2023-12-11 22:39:16.748581+00:00
# 147  2023-12-11 22:39:16.748581+00:00
# 148  2023-12-11 22:39:16.748581+00:00
# 149  2023-12-11 22:39:16.748581+00:00

# %%
df
# Out:
#        id         name symbol          slug  num_market_pairs  \
# 0       1      Bitcoin    BTC       bitcoin             10616
# 1    1027     Ethereum    ETH      ethereum              8032
# 2     825  Tether USDt   USDT        tether             68037
# 3    1839          BNB    BNB           bnb              1840
# 4      52          XRP    XRP           xrp              1170
# 5    5426       Solana    SOL        solana               559
# 6    3408         USDC   USDC      usd-coin             15519
# 7    2010      Cardano    ADA       cardano              1000
# 8    5805    Avalanche   AVAX     avalanche               594
# 9      74     Dogecoin   DOGE      dogecoin               841
# 10   6636     Polkadot    DOT  polkadot-new               636
# 11   1958         TRON    TRX          tron               885
# 12   3890      Polygon  MATIC       polygon              1154
# 13   1975    Chainlink   LINK     chainlink              1497
# 14  11419      Toncoin    TON       toncoin               178
#
#                   date_added  \
# 0   2010-07-13T00:00:00.000Z
# 1   2015-08-07T00:00:00.000Z
# 2   2015-02-25T00:00:00.000Z
# 3   2017-07-25T00:00:00.000Z
# 4   2013-08-04T00:00:00.000Z
# 5   2020-04-10T00:00:00.000Z
# 6   2018-10-08T00:00:00.000Z
# 7   2017-10-01T00:00:00.000Z
# 8   2020-07-13T00:00:00.000Z
# 9   2013-12-15T00:00:00.000Z
# 10  2020-08-19T00:00:00.000Z
# 11  2017-09-13T00:00:00.000Z
# 12  2019-04-28T00:00:00.000Z
# 13  2017-09-20T00:00:00.000Z
# 14  2021-08-26T13:40:22.000Z
#
#                                                  tags          max_supply  \
# 0   [mineable, pow, sha-256, store-of-value, state...     21000000.000000
# 1   [pos, smart-contracts, ethereum-ecosystem, coi...                 NaN
# 2   [payments, stablecoin, asset-backed-stablecoin...                 NaN
# 3   [marketplace, centralized-exchange, payments, ...                 NaN
# 4   [medium-of-exchange, enterprise-solutions, arr... 100000000000.000000
# 5   [pos, platform, solana-ecosystem, cms-holdings...                 NaN
# 6   [medium-of-exchange, stablecoin, asset-backed-...                 NaN
# 7   [dpos, pos, platform, research, smart-contract...  45000000000.000000
# 8   [defi, smart-contracts, three-arrows-capital-p...    720000000.000000
# 9   [mineable, pow, scrypt, medium-of-exchange, me...                 NaN
# 10  [substrate, polkadot, binance-chain, polkadot-...                 NaN
# 11  [media, payments, tron-ecosystem, dwf-labs-por...                 NaN
# 12  [pos, platform, enterprise-solutions, zero-kno...  10000000000.000000
# 13  [platform, defi, oracles, smart-contracts, sub...   1000000000.000000
# 14  [pos, ftx-bankruptcy-estate, dwf-labs-portfoli...                 NaN
#
#     circulating_supply        total_supply  infinite_supply  platform  \
# 0      19569312.000000     19569312.000000            False       NaN
# 1     120209039.963688    120209039.963688             True       NaN
# 2   90659011200.682281  93609080552.557663             True       NaN
# 3     151696099.753937    151696099.753937            False       NaN
# 4   53957460981.000000  99988170772.000000            False       NaN
# 5     427431580.258106    564703002.306319             True       NaN
# 6   24375700393.254959  24375700393.254959            False       NaN
# 7   35328170937.780998  36439975031.086998            False       NaN
# 8     366219078.374693    434251988.374693            False       NaN
# 9  142224086383.705200 142224086383.705200             True       NaN
# 10   1256120887.632055   1388381389.340406             True       NaN
# 11  88437988286.025299  88438032333.383804             True       NaN
# 12   9547813589.337385  10000000000.000000            False       NaN
# 13    556849970.452787   1000000000.000000            False       NaN
# 14   3454926975.751270   5099524104.482027             True       NaN
#
#     cmc_rank  self_reported_circulating_supply  self_reported_market_cap  \
# 0          1                               NaN                       NaN
# 1          2                               NaN                       NaN
# 2          3                               NaN                       NaN
# 3          4                               NaN                       NaN
# 4          5                               NaN                       NaN
# 5          6                               NaN                       NaN
# 6          7                               NaN                       NaN
# 7          8                               NaN                       NaN
# 8          9                               NaN                       NaN
# 9         10                               NaN                       NaN
# 10        11                               NaN                       NaN
# 11        12                71659659264.000000         7461461274.285884
# 12        13                               NaN                       NaN
# 13        14                               NaN                       NaN
# 14        15                 3414166606.000000         7434219237.174948
#
#    tvl_ratio              last_updated  quote.USD.price  quote.USD.volume_24h  \
# 0       None  2023-12-14T03:27:00.000Z     42716.697607    25548898640.474075
# 1       None  2023-12-14T03:27:00.000Z      2252.248683    11715602490.500063
# 2       None  2023-12-14T03:26:00.000Z         1.000312    49821542618.844597
# 3       None  2023-12-14T03:26:00.000Z       249.272280      954548002.663935
# 4       None  2023-12-14T03:27:00.000Z         0.621823     1498081518.767606
# 5       None  2023-12-14T03:27:00.000Z        69.902003     2223044472.248649
# 6       None  2023-12-14T03:27:00.000Z         1.000060     6265762796.204715
# 7       None  2023-12-14T03:26:00.000Z         0.652398     1974391100.986253
# 8       None  2023-12-14T03:26:00.000Z        38.436646     2385414003.723988
# 9       None  2023-12-14T03:27:00.000Z         0.095522      746445904.647444
# 10      None  2023-12-14T03:26:00.000Z         7.425651      454541623.605666
# 11      None  2023-12-14T03:26:00.000Z         0.104124      246833632.424855
# 12      None  2023-12-14T03:26:00.000Z         0.877084      561766378.021757
# 13      None  2023-12-14T03:26:00.000Z        14.711515      583932843.942838
# 14      None  2023-12-14T03:27:00.000Z         2.177462       48793092.003558
#
#     quote.USD.volume_change_24h  quote.USD.percent_change_1h  \
# 0                      2.665200                    -0.239513
# 1                      0.055300                     0.048346
# 2                     -3.297800                     0.007006
# 3                    -32.408600                    -0.217930
# 4                      1.812400                    -0.230150
# 5                     -3.433600                    -0.264444
# 6                     -1.801700                     0.003899
# 7                     58.858100                    -1.711693
# 8                      5.750900                    -1.497961
# 9                    -20.637900                    -0.642014
# 10                   -19.272800                    -1.012368
# 11                    -1.036200                    -0.121615
# 12                   -18.191300                    -0.635342
# 13                    -7.668000                    -0.079332
# 14                    29.767700                    -1.059229
#
#     quote.USD.percent_change_24h  quote.USD.percent_change_7d  \
# 0                       4.581726                    -2.848970
# 1                       4.011278                     0.197985
# 2                       0.029298                     0.008849
# 3                       0.638528                     7.393062
# 4                       2.216319                    -1.642567
# 5                       5.663806                    11.352401
# 6                      -0.021139                     0.004444
# 7                      17.103022                    46.435030
# 8                       9.540374                    46.470062
# 9                       4.389901                    -1.845574
# 10                      8.927414                    22.540170
# 11                      1.239343                    -0.697955
# 12                      3.304139                     6.251342
# 13                      4.231905                    -4.763538
# 14                      5.784335                    -5.059444
#
#     quote.USD.percent_change_30d  quote.USD.percent_change_60d  \
# 0                      17.125177                     58.787309
# 1                       9.478336                     44.762857
# 2                      -0.001631                      0.017401
# 3                       2.826459                     20.185621
# 4                      -5.926147                     27.769564
# 5                      28.058764                    217.639917
# 6                      -0.011281                     -0.016277
# 7                      82.272854                    163.298623
# 8                     129.940884                    317.052320
# 9                      27.488918                     60.345922
# 10                     38.588694                     98.393334
# 11                     -1.920391                     22.390689
# 12                     -1.968171                     68.842448
# 13                      0.000230                    100.366100
# 14                     -7.181369                     12.819119
#
#     quote.USD.percent_change_90d  quote.USD.market_cap  \
# 0                      60.650723   835936383083.774658
# 1                      37.903580   270740651961.743896
# 2                       0.012238    90687313442.312378
# 3                      17.153621    37813632627.894501
# 4                      25.150395    33552001416.623226
# 5                     266.471622    29878323711.440723
# 6                      -0.004714    24377155441.515450
# 7                     156.762458    23048028934.278648
# 8                     305.260228    14076232948.791712
# 9                      53.673939    13585526935.240299
# 10                     81.577652     9327515949.884079
# 11                     24.428899     9208481194.989880
# 12                     66.481635     8374234481.198186
# 13                    136.747769     8192106934.547020
# 14                     13.818900     7522973407.632456
#
#     quote.USD.market_cap_dominance  quote.USD.fully_diluted_market_cap  \
# 0                        52.176200                 897050649749.939941
# 1                        16.898700                 270740651961.739990
# 2                         5.660400                  93638303756.970001
# 3                         2.360900                  37813632627.889999
# 4                         2.094200                  62182320677.459999
# 5                         1.864900                  39473871101.290001
# 6                         1.522000                  24377155441.520000
# 7                         1.438600                  29357911109.220001
# 8                         0.878600                  27674384873.970001
# 9                         0.848000                  13585526935.240000
# 10                        0.582400                  10309636342.410000
# 11                        0.574800                   9208485781.360001
# 12                        0.522700                   8770839944.500000
# 13                        0.511300                  14711515433.660000
# 14                        0.469600                  11104021734.430000
#
#    quote.USD.tvl    quote.USD.last_updated  platform.id platform.name  \
# 0           None  2023-12-14T03:27:00.000Z          NaN           NaN
# 1           None  2023-12-14T03:27:00.000Z          NaN           NaN
# 2           None  2023-12-14T03:26:00.000Z  1027.000000      Ethereum
# 3           None  2023-12-14T03:26:00.000Z          NaN           NaN
# 4           None  2023-12-14T03:27:00.000Z          NaN           NaN
# 5           None  2023-12-14T03:27:00.000Z          NaN           NaN
# 6           None  2023-12-14T03:27:00.000Z  1027.000000      Ethereum
# 7           None  2023-12-14T03:26:00.000Z          NaN           NaN
# 8           None  2023-12-14T03:26:00.000Z          NaN           NaN
# 9           None  2023-12-14T03:27:00.000Z          NaN           NaN
# 10          None  2023-12-14T03:26:00.000Z          NaN           NaN
# 11          None  2023-12-14T03:26:00.000Z          NaN           NaN
# 12          None  2023-12-14T03:26:00.000Z          NaN           NaN
# 13          None  2023-12-14T03:26:00.000Z  1027.000000      Ethereum
# 14          None  2023-12-14T03:27:00.000Z          NaN           NaN
#
#    platform.symbol platform.slug                      platform.token_address  \
# 0              NaN           NaN                                         NaN
# 1              NaN           NaN                                         NaN
# 2              ETH      ethereum  0xdac17f958d2ee523a2206206994597c13d831ec7
# 3              NaN           NaN                                         NaN
# 4              NaN           NaN                                         NaN
# 5              NaN           NaN                                         NaN
# 6              ETH      ethereum  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 7              NaN           NaN                                         NaN
# 8              NaN           NaN                                         NaN
# 9              NaN           NaN                                         NaN
# 10             NaN           NaN                                         NaN
# 11             NaN           NaN                                         NaN
# 12             NaN           NaN                                         NaN
# 13             ETH      ethereum  0x514910771af9ca656af840dff83e8264ecf986ca
# 14             NaN           NaN                                         NaN
#
#                           timestamp
# 0  2023-12-14 03:28:26.227710+00:00
# 1  2023-12-14 03:28:26.227710+00:00
# 2  2023-12-14 03:28:26.227710+00:00
# 3  2023-12-14 03:28:26.227710+00:00
# 4  2023-12-14 03:28:26.227710+00:00
# 5  2023-12-14 03:28:26.227710+00:00
# 6  2023-12-14 03:28:26.227710+00:00
# 7  2023-12-14 03:28:26.227710+00:00
# 8  2023-12-14 03:28:26.227710+00:00
# 9  2023-12-14 03:28:26.227710+00:00
# 10 2023-12-14 03:28:26.227710+00:00
# 11 2023-12-14 03:28:26.227710+00:00
# 12 2023-12-14 03:28:26.227710+00:00
# 13 2023-12-14 03:28:26.227710+00:00
# 14 2023-12-14 03:28:26.227710+00:00

# %%
# Set the display format for floating-point numbers in the DataFrame to show 5 decimal places
pd.set_option('display.float_format', lambda x: '%.5f' % x)

# %%
df
# Out:
#        id         name symbol          slug  num_market_pairs  \
# 0       1      Bitcoin    BTC       bitcoin             10616
# 1    1027     Ethereum    ETH      ethereum              8032
# 2     825  Tether USDt   USDT        tether             68037
# 3    1839          BNB    BNB           bnb              1840
# 4      52          XRP    XRP           xrp              1170
# 5    5426       Solana    SOL        solana               559
# 6    3408         USDC   USDC      usd-coin             15519
# 7    2010      Cardano    ADA       cardano              1000
# 8    5805    Avalanche   AVAX     avalanche               594
# 9      74     Dogecoin   DOGE      dogecoin               841
# 10   6636     Polkadot    DOT  polkadot-new               636
# 11   1958         TRON    TRX          tron               885
# 12   3890      Polygon  MATIC       polygon              1154
# 13   1975    Chainlink   LINK     chainlink              1497
# 14  11419      Toncoin    TON       toncoin               178
#
#                   date_added  \
# 0   2010-07-13T00:00:00.000Z
# 1   2015-08-07T00:00:00.000Z
# 2   2015-02-25T00:00:00.000Z
# 3   2017-07-25T00:00:00.000Z
# 4   2013-08-04T00:00:00.000Z
# 5   2020-04-10T00:00:00.000Z
# 6   2018-10-08T00:00:00.000Z
# 7   2017-10-01T00:00:00.000Z
# 8   2020-07-13T00:00:00.000Z
# 9   2013-12-15T00:00:00.000Z
# 10  2020-08-19T00:00:00.000Z
# 11  2017-09-13T00:00:00.000Z
# 12  2019-04-28T00:00:00.000Z
# 13  2017-09-20T00:00:00.000Z
# 14  2021-08-26T13:40:22.000Z
#
#                                                  tags          max_supply  \
# 0   [mineable, pow, sha-256, store-of-value, state...     21000000.000000
# 1   [pos, smart-contracts, ethereum-ecosystem, coi...                 NaN
# 2   [payments, stablecoin, asset-backed-stablecoin...                 NaN
# 3   [marketplace, centralized-exchange, payments, ...                 NaN
# 4   [medium-of-exchange, enterprise-solutions, arr... 100000000000.000000
# 5   [pos, platform, solana-ecosystem, cms-holdings...                 NaN
# 6   [medium-of-exchange, stablecoin, asset-backed-...                 NaN
# 7   [dpos, pos, platform, research, smart-contract...  45000000000.000000
# 8   [defi, smart-contracts, three-arrows-capital-p...    720000000.000000
# 9   [mineable, pow, scrypt, medium-of-exchange, me...                 NaN
# 10  [substrate, polkadot, binance-chain, polkadot-...                 NaN
# 11  [media, payments, tron-ecosystem, dwf-labs-por...                 NaN
# 12  [pos, platform, enterprise-solutions, zero-kno...  10000000000.000000
# 13  [platform, defi, oracles, smart-contracts, sub...   1000000000.000000
# 14  [pos, ftx-bankruptcy-estate, dwf-labs-portfoli...                 NaN
#
#     circulating_supply        total_supply  infinite_supply  platform  \
# 0      19569312.000000     19569312.000000            False       NaN
# 1     120209039.963688    120209039.963688             True       NaN
# 2   90659011200.682281  93609080552.557663             True       NaN
# 3     151696099.753937    151696099.753937            False       NaN
# 4   53957460981.000000  99988170772.000000            False       NaN
# 5     427431580.258106    564703002.306319             True       NaN
# 6   24375700393.254959  24375700393.254959            False       NaN
# 7   35328170937.780998  36439975031.086998            False       NaN
# 8     366219078.374693    434251988.374693            False       NaN
# 9  142224086383.705200 142224086383.705200             True       NaN
# 10   1256120887.632055   1388381389.340406             True       NaN
# 11  88437988286.025299  88438032333.383804             True       NaN
# 12   9547813589.337385  10000000000.000000            False       NaN
# 13    556849970.452787   1000000000.000000            False       NaN
# 14   3454926975.751270   5099524104.482027             True       NaN
#
#     cmc_rank  self_reported_circulating_supply  self_reported_market_cap  \
# 0          1                               NaN                       NaN
# 1          2                               NaN                       NaN
# 2          3                               NaN                       NaN
# 3          4                               NaN                       NaN
# 4          5                               NaN                       NaN
# 5          6                               NaN                       NaN
# 6          7                               NaN                       NaN
# 7          8                               NaN                       NaN
# 8          9                               NaN                       NaN
# 9         10                               NaN                       NaN
# 10        11                               NaN                       NaN
# 11        12                71659659264.000000         7461461274.285884
# 12        13                               NaN                       NaN
# 13        14                               NaN                       NaN
# 14        15                 3414166606.000000         7434219237.174948
#
#    tvl_ratio              last_updated  quote.USD.price  quote.USD.volume_24h  \
# 0       None  2023-12-14T03:27:00.000Z     42716.697607    25548898640.474075
# 1       None  2023-12-14T03:27:00.000Z      2252.248683    11715602490.500063
# 2       None  2023-12-14T03:26:00.000Z         1.000312    49821542618.844597
# 3       None  2023-12-14T03:26:00.000Z       249.272280      954548002.663935
# 4       None  2023-12-14T03:27:00.000Z         0.621823     1498081518.767606
# 5       None  2023-12-14T03:27:00.000Z        69.902003     2223044472.248649
# 6       None  2023-12-14T03:27:00.000Z         1.000060     6265762796.204715
# 7       None  2023-12-14T03:26:00.000Z         0.652398     1974391100.986253
# 8       None  2023-12-14T03:26:00.000Z        38.436646     2385414003.723988
# 9       None  2023-12-14T03:27:00.000Z         0.095522      746445904.647444
# 10      None  2023-12-14T03:26:00.000Z         7.425651      454541623.605666
# 11      None  2023-12-14T03:26:00.000Z         0.104124      246833632.424855
# 12      None  2023-12-14T03:26:00.000Z         0.877084      561766378.021757
# 13      None  2023-12-14T03:26:00.000Z        14.711515      583932843.942838
# 14      None  2023-12-14T03:27:00.000Z         2.177462       48793092.003558
#
#     quote.USD.volume_change_24h  quote.USD.percent_change_1h  \
# 0                      2.665200                    -0.239513
# 1                      0.055300                     0.048346
# 2                     -3.297800                     0.007006
# 3                    -32.408600                    -0.217930
# 4                      1.812400                    -0.230150
# 5                     -3.433600                    -0.264444
# 6                     -1.801700                     0.003899
# 7                     58.858100                    -1.711693
# 8                      5.750900                    -1.497961
# 9                    -20.637900                    -0.642014
# 10                   -19.272800                    -1.012368
# 11                    -1.036200                    -0.121615
# 12                   -18.191300                    -0.635342
# 13                    -7.668000                    -0.079332
# 14                    29.767700                    -1.059229
#
#     quote.USD.percent_change_24h  quote.USD.percent_change_7d  \
# 0                       4.581726                    -2.848970
# 1                       4.011278                     0.197985
# 2                       0.029298                     0.008849
# 3                       0.638528                     7.393062
# 4                       2.216319                    -1.642567
# 5                       5.663806                    11.352401
# 6                      -0.021139                     0.004444
# 7                      17.103022                    46.435030
# 8                       9.540374                    46.470062
# 9                       4.389901                    -1.845574
# 10                      8.927414                    22.540170
# 11                      1.239343                    -0.697955
# 12                      3.304139                     6.251342
# 13                      4.231905                    -4.763538
# 14                      5.784335                    -5.059444
#
#     quote.USD.percent_change_30d  quote.USD.percent_change_60d  \
# 0                      17.125177                     58.787309
# 1                       9.478336                     44.762857
# 2                      -0.001631                      0.017401
# 3                       2.826459                     20.185621
# 4                      -5.926147                     27.769564
# 5                      28.058764                    217.639917
# 6                      -0.011281                     -0.016277
# 7                      82.272854                    163.298623
# 8                     129.940884                    317.052320
# 9                      27.488918                     60.345922
# 10                     38.588694                     98.393334
# 11                     -1.920391                     22.390689
# 12                     -1.968171                     68.842448
# 13                      0.000230                    100.366100
# 14                     -7.181369                     12.819119
#
#     quote.USD.percent_change_90d  quote.USD.market_cap  \
# 0                      60.650723   835936383083.774658
# 1                      37.903580   270740651961.743896
# 2                       0.012238    90687313442.312378
# 3                      17.153621    37813632627.894501
# 4                      25.150395    33552001416.623226
# 5                     266.471622    29878323711.440723
# 6                      -0.004714    24377155441.515450
# 7                     156.762458    23048028934.278648
# 8                     305.260228    14076232948.791712
# 9                      53.673939    13585526935.240299
# 10                     81.577652     9327515949.884079
# 11                     24.428899     9208481194.989880
# 12                     66.481635     8374234481.198186
# 13                    136.747769     8192106934.547020
# 14                     13.818900     7522973407.632456
#
#     quote.USD.market_cap_dominance  quote.USD.fully_diluted_market_cap  \
# 0                        52.176200                 897050649749.939941
# 1                        16.898700                 270740651961.739990
# 2                         5.660400                  93638303756.970001
# 3                         2.360900                  37813632627.889999
# 4                         2.094200                  62182320677.459999
# 5                         1.864900                  39473871101.290001
# 6                         1.522000                  24377155441.520000
# 7                         1.438600                  29357911109.220001
# 8                         0.878600                  27674384873.970001
# 9                         0.848000                  13585526935.240000
# 10                        0.582400                  10309636342.410000
# 11                        0.574800                   9208485781.360001
# 12                        0.522700                   8770839944.500000
# 13                        0.511300                  14711515433.660000
# 14                        0.469600                  11104021734.430000
#
#    quote.USD.tvl    quote.USD.last_updated  platform.id platform.name  \
# 0           None  2023-12-14T03:27:00.000Z          NaN           NaN
# 1           None  2023-12-14T03:27:00.000Z          NaN           NaN
# 2           None  2023-12-14T03:26:00.000Z  1027.000000      Ethereum
# 3           None  2023-12-14T03:26:00.000Z          NaN           NaN
# 4           None  2023-12-14T03:27:00.000Z          NaN           NaN
# 5           None  2023-12-14T03:27:00.000Z          NaN           NaN
# 6           None  2023-12-14T03:27:00.000Z  1027.000000      Ethereum
# 7           None  2023-12-14T03:26:00.000Z          NaN           NaN
# 8           None  2023-12-14T03:26:00.000Z          NaN           NaN
# 9           None  2023-12-14T03:27:00.000Z          NaN           NaN
# 10          None  2023-12-14T03:26:00.000Z          NaN           NaN
# 11          None  2023-12-14T03:26:00.000Z          NaN           NaN
# 12          None  2023-12-14T03:26:00.000Z          NaN           NaN
# 13          None  2023-12-14T03:26:00.000Z  1027.000000      Ethereum
# 14          None  2023-12-14T03:27:00.000Z          NaN           NaN
#
#    platform.symbol platform.slug                      platform.token_address  \
# 0              NaN           NaN                                         NaN
# 1              NaN           NaN                                         NaN
# 2              ETH      ethereum  0xdac17f958d2ee523a2206206994597c13d831ec7
# 3              NaN           NaN                                         NaN
# 4              NaN           NaN                                         NaN
# 5              NaN           NaN                                         NaN
# 6              ETH      ethereum  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 7              NaN           NaN                                         NaN
# 8              NaN           NaN                                         NaN
# 9              NaN           NaN                                         NaN
# 10             NaN           NaN                                         NaN
# 11             NaN           NaN                                         NaN
# 12             NaN           NaN                                         NaN
# 13             ETH      ethereum  0x514910771af9ca656af840dff83e8264ecf986ca
# 14             NaN           NaN                                         NaN
#
#                           timestamp
# 0  2023-12-14 03:28:26.227710+00:00
# 1  2023-12-14 03:28:26.227710+00:00
# 2  2023-12-14 03:28:26.227710+00:00
# 3  2023-12-14 03:28:26.227710+00:00
# 4  2023-12-14 03:28:26.227710+00:00
# 5  2023-12-14 03:28:26.227710+00:00
# 6  2023-12-14 03:28:26.227710+00:00
# 7  2023-12-14 03:28:26.227710+00:00
# 8  2023-12-14 03:28:26.227710+00:00
# 9  2023-12-14 03:28:26.227710+00:00
# 10 2023-12-14 03:28:26.227710+00:00
# 11 2023-12-14 03:28:26.227710+00:00
# 12 2023-12-14 03:28:26.227710+00:00
# 13 2023-12-14 03:28:26.227710+00:00
# 14 2023-12-14 03:28:26.227710+00:00

# %%
# Group the DataFrame by the 'name' column without sorting
# Calculate the mean for selected percentage change columns over different time intervals
df3 = df.groupby('name', sort=False)[['quote.USD.percent_change_1h', 'quote.USD.percent_change_24h', 
                                      'quote.USD.percent_change_7d', 'quote.USD.percent_change_30d',
                                      'quote.USD.percent_change_60d', 'quote.USD.percent_change_90d']].mean()
# Out:
#              quote.USD.percent_change_1h  quote.USD.percent_change_24h  \
# name
# Bitcoin                        -0.239513                      4.581726
# Ethereum                        0.048346                      4.011278
# Tether USDt                     0.007006                      0.029298
# BNB                            -0.217930                      0.638528
# XRP                            -0.230150                      2.216319
# Solana                         -0.264444                      5.663806
# USDC                            0.003899                     -0.021139
# Cardano                        -1.711693                     17.103022
# Avalanche                      -1.497961                      9.540374
# Dogecoin                       -0.642014                      4.389901
# Polkadot                       -1.012368                      8.927414
# TRON                           -0.121615                      1.239343
# Polygon                        -0.635342                      3.304139
# Chainlink                      -0.079332                      4.231905
# Toncoin                        -1.059229                      5.784335
#
#              quote.USD.percent_change_7d  quote.USD.percent_change_30d  \
# name
# Bitcoin                        -2.848970                     17.125177
# Ethereum                        0.197985                      9.478336
# Tether USDt                     0.008849                     -0.001631
# BNB                             7.393062                      2.826459
# XRP                            -1.642567                     -5.926147
# Solana                         11.352401                     28.058764
# USDC                            0.004444                     -0.011281
# Cardano                        46.435030                     82.272854
# Avalanche                      46.470062                    129.940884
# Dogecoin                       -1.845574                     27.488918
# Polkadot                       22.540170                     38.588694
# TRON                           -0.697955                     -1.920391
# Polygon                         6.251342                     -1.968171
# Chainlink                      -4.763538                      0.000230
# Toncoin                        -5.059444                     -7.181369
#
#              quote.USD.percent_change_60d  quote.USD.percent_change_90d
# name
# Bitcoin                         58.787309                     60.650723
# Ethereum                        44.762857                     37.903580
# Tether USDt                      0.017401                      0.012238
# BNB                             20.185621                     17.153621
# XRP                             27.769564                     25.150395
# Solana                         217.639917                    266.471622
# USDC                            -0.016277                     -0.004714
# Cardano                        163.298623                    156.762458
# Avalanche                      317.052320                    305.260228
# Dogecoin                        60.345922                     53.673939
# Polkadot                        98.393334                     81.577652
# TRON                            22.390689                     24.428899
# Polygon                         68.842448                     66.481635
# Chainlink                      100.366100                    136.747769
# Toncoin                         12.819119                     13.818900

# %%
df4 = df3.stack()
df4
# Out:
# name
# Bitcoin      quote.USD.percent_change_1h     -0.239513
#              quote.USD.percent_change_24h     4.581726
#              quote.USD.percent_change_7d     -2.848970
#              quote.USD.percent_change_30d    17.125177
#              quote.USD.percent_change_60d    58.787309
#              quote.USD.percent_change_90d    60.650723
# Ethereum     quote.USD.percent_change_1h      0.048346
#              quote.USD.percent_change_24h     4.011278
#              quote.USD.percent_change_7d      0.197985
#              quote.USD.percent_change_30d     9.478336
#              quote.USD.percent_change_60d    44.762857
#              quote.USD.percent_change_90d    37.903580
# Tether USDt  quote.USD.percent_change_1h      0.007006
#              quote.USD.percent_change_24h     0.029298
#              quote.USD.percent_change_7d      0.008849
#              quote.USD.percent_change_30d    -0.001631
#              quote.USD.percent_change_60d     0.017401
#              quote.USD.percent_change_90d     0.012238
# BNB          quote.USD.percent_change_1h     -0.217930
#              quote.USD.percent_change_24h     0.638528
#              quote.USD.percent_change_7d      7.393062
#              quote.USD.percent_change_30d     2.826459
#              quote.USD.percent_change_60d    20.185621
#              quote.USD.percent_change_90d    17.153621
# XRP          quote.USD.percent_change_1h     -0.230150
#              quote.USD.percent_change_24h     2.216319
#              quote.USD.percent_change_7d     -1.642567
#              quote.USD.percent_change_30d    -5.926147
#              quote.USD.percent_change_60d    27.769564
#              quote.USD.percent_change_90d    25.150395
# Solana       quote.USD.percent_change_1h     -0.264444
#              quote.USD.percent_change_24h     5.663806
#              quote.USD.percent_change_7d     11.352401
#              quote.USD.percent_change_30d    28.058764
#              quote.USD.percent_change_60d   217.639917
#              quote.USD.percent_change_90d   266.471622
# USDC         quote.USD.percent_change_1h      0.003899
#              quote.USD.percent_change_24h    -0.021139
#              quote.USD.percent_change_7d      0.004444
#              quote.USD.percent_change_30d    -0.011281
#              quote.USD.percent_change_60d    -0.016277
#              quote.USD.percent_change_90d    -0.004714
# Cardano      quote.USD.percent_change_1h     -1.711693
#              quote.USD.percent_change_24h    17.103022
#              quote.USD.percent_change_7d     46.435030
#              quote.USD.percent_change_30d    82.272854
#              quote.USD.percent_change_60d   163.298623
#              quote.USD.percent_change_90d   156.762458
# Avalanche    quote.USD.percent_change_1h     -1.497961
#              quote.USD.percent_change_24h     9.540374
#              quote.USD.percent_change_7d     46.470062
#              quote.USD.percent_change_30d   129.940884
#              quote.USD.percent_change_60d   317.052320
#              quote.USD.percent_change_90d   305.260228
# Dogecoin     quote.USD.percent_change_1h     -0.642014
#              quote.USD.percent_change_24h     4.389901
#              quote.USD.percent_change_7d     -1.845574
#              quote.USD.percent_change_30d    27.488918
#              quote.USD.percent_change_60d    60.345922
#              quote.USD.percent_change_90d    53.673939
# Polkadot     quote.USD.percent_change_1h     -1.012368
#              quote.USD.percent_change_24h     8.927414
#              quote.USD.percent_change_7d     22.540170
#              quote.USD.percent_change_30d    38.588694
#              quote.USD.percent_change_60d    98.393334
#              quote.USD.percent_change_90d    81.577652
# TRON         quote.USD.percent_change_1h     -0.121615
#              quote.USD.percent_change_24h     1.239343
#              quote.USD.percent_change_7d     -0.697955
#              quote.USD.percent_change_30d    -1.920391
#              quote.USD.percent_change_60d    22.390689
#              quote.USD.percent_change_90d    24.428899
# Polygon      quote.USD.percent_change_1h     -0.635342
#              quote.USD.percent_change_24h     3.304139
#              quote.USD.percent_change_7d      6.251342
#              quote.USD.percent_change_30d    -1.968171
#              quote.USD.percent_change_60d    68.842448
#              quote.USD.percent_change_90d    66.481635
# Chainlink    quote.USD.percent_change_1h     -0.079332
#              quote.USD.percent_change_24h     4.231905
#              quote.USD.percent_change_7d     -4.763538
#              quote.USD.percent_change_30d     0.000230
#              quote.USD.percent_change_60d   100.366100
#              quote.USD.percent_change_90d   136.747769
# Toncoin      quote.USD.percent_change_1h     -1.059229
#              quote.USD.percent_change_24h     5.784335
#              quote.USD.percent_change_7d     -5.059444
#              quote.USD.percent_change_30d    -7.181369
#              quote.USD.percent_change_60d    12.819119
#              quote.USD.percent_change_90d    13.818900
# dtype: float64

# %%
type(df4)
# Out:
# pandas.core.series.Series

# %%
# Convert the stacked Series to a DataFrame with a column named 'values'
df5 = df4.to_frame(name='values')
df5
# Out:
#                                              values
# name
# Bitcoin     quote.USD.percent_change_1h   -0.239513
#             quote.USD.percent_change_24h   4.581726
#             quote.USD.percent_change_7d   -2.848970
#             quote.USD.percent_change_30d  17.125177
#             quote.USD.percent_change_60d  58.787309
#             quote.USD.percent_change_90d  60.650723
# Ethereum    quote.USD.percent_change_1h    0.048346
#             quote.USD.percent_change_24h   4.011278
#             quote.USD.percent_change_7d    0.197985
#             quote.USD.percent_change_30d   9.478336
#             quote.USD.percent_change_60d  44.762857
#             quote.USD.percent_change_90d  37.903580
# Tether USDt quote.USD.percent_change_1h    0.007006
#             quote.USD.percent_change_24h   0.029298
#             quote.USD.percent_change_7d    0.008849
#             quote.USD.percent_change_30d  -0.001631
#             quote.USD.percent_change_60d   0.017401
#             quote.USD.percent_change_90d   0.012238
# BNB         quote.USD.percent_change_1h   -0.217930
#             quote.USD.percent_change_24h   0.638528
#             quote.USD.percent_change_7d    7.393062
#             quote.USD.percent_change_30d   2.826459
#             quote.USD.percent_change_60d  20.185621
#             quote.USD.percent_change_90d  17.153621
# XRP         quote.USD.percent_change_1h   -0.230150
#             quote.USD.percent_change_24h   2.216319
#             quote.USD.percent_change_7d   -1.642567
#             quote.USD.percent_change_30d  -5.926147
#             quote.USD.percent_change_60d  27.769564
#             quote.USD.percent_change_90d  25.150395
# Solana      quote.USD.percent_change_1h   -0.264444
#             quote.USD.percent_change_24h   5.663806
#             quote.USD.percent_change_7d   11.352401
#             quote.USD.percent_change_30d  28.058764
#             quote.USD.percent_change_60d 217.639917
#             quote.USD.percent_change_90d 266.471622
# USDC        quote.USD.percent_change_1h    0.003899
#             quote.USD.percent_change_24h  -0.021139
#             quote.USD.percent_change_7d    0.004444
#             quote.USD.percent_change_30d  -0.011281
#             quote.USD.percent_change_60d  -0.016277
#             quote.USD.percent_change_90d  -0.004714
# Cardano     quote.USD.percent_change_1h   -1.711693
#             quote.USD.percent_change_24h  17.103022
#             quote.USD.percent_change_7d   46.435030
#             quote.USD.percent_change_30d  82.272854
#             quote.USD.percent_change_60d 163.298623
#             quote.USD.percent_change_90d 156.762458
# Avalanche   quote.USD.percent_change_1h   -1.497961
#             quote.USD.percent_change_24h   9.540374
#             quote.USD.percent_change_7d   46.470062
#             quote.USD.percent_change_30d 129.940884
#             quote.USD.percent_change_60d 317.052320
#             quote.USD.percent_change_90d 305.260228
# Dogecoin    quote.USD.percent_change_1h   -0.642014
#             quote.USD.percent_change_24h   4.389901
#             quote.USD.percent_change_7d   -1.845574
#             quote.USD.percent_change_30d  27.488918
#             quote.USD.percent_change_60d  60.345922
#             quote.USD.percent_change_90d  53.673939
# Polkadot    quote.USD.percent_change_1h   -1.012368
#             quote.USD.percent_change_24h   8.927414
#             quote.USD.percent_change_7d   22.540170
#             quote.USD.percent_change_30d  38.588694
#             quote.USD.percent_change_60d  98.393334
#             quote.USD.percent_change_90d  81.577652
# TRON        quote.USD.percent_change_1h   -0.121615
#             quote.USD.percent_change_24h   1.239343
#             quote.USD.percent_change_7d   -0.697955
#             quote.USD.percent_change_30d  -1.920391
#             quote.USD.percent_change_60d  22.390689
#             quote.USD.percent_change_90d  24.428899
# Polygon     quote.USD.percent_change_1h   -0.635342
#             quote.USD.percent_change_24h   3.304139
#             quote.USD.percent_change_7d    6.251342
#             quote.USD.percent_change_30d  -1.968171
#             quote.USD.percent_change_60d  68.842448
#             quote.USD.percent_change_90d  66.481635
# Chainlink   quote.USD.percent_change_1h   -0.079332
#             quote.USD.percent_change_24h   4.231905
#             quote.USD.percent_change_7d   -4.763538
#             quote.USD.percent_change_30d   0.000230
#             quote.USD.percent_change_60d 100.366100
#             quote.USD.percent_change_90d 136.747769
# Toncoin     quote.USD.percent_change_1h   -1.059229
#             quote.USD.percent_change_24h   5.784335
#             quote.USD.percent_change_7d   -5.059444
#             quote.USD.percent_change_30d  -7.181369
#             quote.USD.percent_change_60d  12.819119
#             quote.USD.percent_change_90d  13.818900

# %%
df5.count()
# Out:
# values    90
# dtype: int64

# %%
# Create a new DataFrame with a default index range of 0 to 89
index = pd.Index(range(90))

df6 = df5.reset_index()
df6
# Out:
#            name                       level_1     values
# 0       Bitcoin   quote.USD.percent_change_1h  -0.239513
# 1       Bitcoin  quote.USD.percent_change_24h   4.581726
# 2       Bitcoin   quote.USD.percent_change_7d  -2.848970
# 3       Bitcoin  quote.USD.percent_change_30d  17.125177
# 4       Bitcoin  quote.USD.percent_change_60d  58.787309
# 5       Bitcoin  quote.USD.percent_change_90d  60.650723
# 6      Ethereum   quote.USD.percent_change_1h   0.048346
# 7      Ethereum  quote.USD.percent_change_24h   4.011278
# 8      Ethereum   quote.USD.percent_change_7d   0.197985
# 9      Ethereum  quote.USD.percent_change_30d   9.478336
# 10     Ethereum  quote.USD.percent_change_60d  44.762857
# 11     Ethereum  quote.USD.percent_change_90d  37.903580
# 12  Tether USDt   quote.USD.percent_change_1h   0.007006
# 13  Tether USDt  quote.USD.percent_change_24h   0.029298
# 14  Tether USDt   quote.USD.percent_change_7d   0.008849
# 15  Tether USDt  quote.USD.percent_change_30d  -0.001631
# 16  Tether USDt  quote.USD.percent_change_60d   0.017401
# 17  Tether USDt  quote.USD.percent_change_90d   0.012238
# 18          BNB   quote.USD.percent_change_1h  -0.217930
# 19          BNB  quote.USD.percent_change_24h   0.638528
# 20          BNB   quote.USD.percent_change_7d   7.393062
# 21          BNB  quote.USD.percent_change_30d   2.826459
# 22          BNB  quote.USD.percent_change_60d  20.185621
# 23          BNB  quote.USD.percent_change_90d  17.153621
# 24          XRP   quote.USD.percent_change_1h  -0.230150
# 25          XRP  quote.USD.percent_change_24h   2.216319
# 26          XRP   quote.USD.percent_change_7d  -1.642567
# 27          XRP  quote.USD.percent_change_30d  -5.926147
# 28          XRP  quote.USD.percent_change_60d  27.769564
# 29          XRP  quote.USD.percent_change_90d  25.150395
# 30       Solana   quote.USD.percent_change_1h  -0.264444
# 31       Solana  quote.USD.percent_change_24h   5.663806
# 32       Solana   quote.USD.percent_change_7d  11.352401
# 33       Solana  quote.USD.percent_change_30d  28.058764
# 34       Solana  quote.USD.percent_change_60d 217.639917
# 35       Solana  quote.USD.percent_change_90d 266.471622
# 36         USDC   quote.USD.percent_change_1h   0.003899
# 37         USDC  quote.USD.percent_change_24h  -0.021139
# 38         USDC   quote.USD.percent_change_7d   0.004444
# 39         USDC  quote.USD.percent_change_30d  -0.011281
# 40         USDC  quote.USD.percent_change_60d  -0.016277
# 41         USDC  quote.USD.percent_change_90d  -0.004714
# 42      Cardano   quote.USD.percent_change_1h  -1.711693
# 43      Cardano  quote.USD.percent_change_24h  17.103022
# 44      Cardano   quote.USD.percent_change_7d  46.435030
# 45      Cardano  quote.USD.percent_change_30d  82.272854
# 46      Cardano  quote.USD.percent_change_60d 163.298623
# 47      Cardano  quote.USD.percent_change_90d 156.762458
# 48    Avalanche   quote.USD.percent_change_1h  -1.497961
# 49    Avalanche  quote.USD.percent_change_24h   9.540374
# 50    Avalanche   quote.USD.percent_change_7d  46.470062
# 51    Avalanche  quote.USD.percent_change_30d 129.940884
# 52    Avalanche  quote.USD.percent_change_60d 317.052320
# 53    Avalanche  quote.USD.percent_change_90d 305.260228
# 54     Dogecoin   quote.USD.percent_change_1h  -0.642014
# 55     Dogecoin  quote.USD.percent_change_24h   4.389901
# 56     Dogecoin   quote.USD.percent_change_7d  -1.845574
# 57     Dogecoin  quote.USD.percent_change_30d  27.488918
# 58     Dogecoin  quote.USD.percent_change_60d  60.345922
# 59     Dogecoin  quote.USD.percent_change_90d  53.673939
# 60     Polkadot   quote.USD.percent_change_1h  -1.012368
# 61     Polkadot  quote.USD.percent_change_24h   8.927414
# 62     Polkadot   quote.USD.percent_change_7d  22.540170
# 63     Polkadot  quote.USD.percent_change_30d  38.588694
# 64     Polkadot  quote.USD.percent_change_60d  98.393334
# 65     Polkadot  quote.USD.percent_change_90d  81.577652
# 66         TRON   quote.USD.percent_change_1h  -0.121615
# 67         TRON  quote.USD.percent_change_24h   1.239343
# 68         TRON   quote.USD.percent_change_7d  -0.697955
# 69         TRON  quote.USD.percent_change_30d  -1.920391
# 70         TRON  quote.USD.percent_change_60d  22.390689
# 71         TRON  quote.USD.percent_change_90d  24.428899
# 72      Polygon   quote.USD.percent_change_1h  -0.635342
# 73      Polygon  quote.USD.percent_change_24h   3.304139
# 74      Polygon   quote.USD.percent_change_7d   6.251342
# 75      Polygon  quote.USD.percent_change_30d  -1.968171
# 76      Polygon  quote.USD.percent_change_60d  68.842448
# 77      Polygon  quote.USD.percent_change_90d  66.481635
# 78    Chainlink   quote.USD.percent_change_1h  -0.079332
# 79    Chainlink  quote.USD.percent_change_24h   4.231905
# 80    Chainlink   quote.USD.percent_change_7d  -4.763538
# 81    Chainlink  quote.USD.percent_change_30d   0.000230
# 82    Chainlink  quote.USD.percent_change_60d 100.366100
# 83    Chainlink  quote.USD.percent_change_90d 136.747769
# 84      Toncoin   quote.USD.percent_change_1h  -1.059229
# 85      Toncoin  quote.USD.percent_change_24h   5.784335
# 86      Toncoin   quote.USD.percent_change_7d  -5.059444
# 87      Toncoin  quote.USD.percent_change_30d  -7.181369
# 88      Toncoin  quote.USD.percent_change_60d  12.819119
# 89      Toncoin  quote.USD.percent_change_90d  13.818900

# %%
# Rename the column 'level_1' to 'percent_change'
df7 = df6.rename(columns={'level_1': 'percent_change'})
df7
# Out:
#            name                percent_change     values
# 0       Bitcoin   quote.USD.percent_change_1h  -0.239513
# 1       Bitcoin  quote.USD.percent_change_24h   4.581726
# 2       Bitcoin   quote.USD.percent_change_7d  -2.848970
# 3       Bitcoin  quote.USD.percent_change_30d  17.125177
# 4       Bitcoin  quote.USD.percent_change_60d  58.787309
# 5       Bitcoin  quote.USD.percent_change_90d  60.650723
# 6      Ethereum   quote.USD.percent_change_1h   0.048346
# 7      Ethereum  quote.USD.percent_change_24h   4.011278
# 8      Ethereum   quote.USD.percent_change_7d   0.197985
# 9      Ethereum  quote.USD.percent_change_30d   9.478336
# 10     Ethereum  quote.USD.percent_change_60d  44.762857
# 11     Ethereum  quote.USD.percent_change_90d  37.903580
# 12  Tether USDt   quote.USD.percent_change_1h   0.007006
# 13  Tether USDt  quote.USD.percent_change_24h   0.029298
# 14  Tether USDt   quote.USD.percent_change_7d   0.008849
# 15  Tether USDt  quote.USD.percent_change_30d  -0.001631
# 16  Tether USDt  quote.USD.percent_change_60d   0.017401
# 17  Tether USDt  quote.USD.percent_change_90d   0.012238
# 18          BNB   quote.USD.percent_change_1h  -0.217930
# 19          BNB  quote.USD.percent_change_24h   0.638528
# 20          BNB   quote.USD.percent_change_7d   7.393062
# 21          BNB  quote.USD.percent_change_30d   2.826459
# 22          BNB  quote.USD.percent_change_60d  20.185621
# 23          BNB  quote.USD.percent_change_90d  17.153621
# 24          XRP   quote.USD.percent_change_1h  -0.230150
# 25          XRP  quote.USD.percent_change_24h   2.216319
# 26          XRP   quote.USD.percent_change_7d  -1.642567
# 27          XRP  quote.USD.percent_change_30d  -5.926147
# 28          XRP  quote.USD.percent_change_60d  27.769564
# 29          XRP  quote.USD.percent_change_90d  25.150395
# 30       Solana   quote.USD.percent_change_1h  -0.264444
# 31       Solana  quote.USD.percent_change_24h   5.663806
# 32       Solana   quote.USD.percent_change_7d  11.352401
# 33       Solana  quote.USD.percent_change_30d  28.058764
# 34       Solana  quote.USD.percent_change_60d 217.639917
# 35       Solana  quote.USD.percent_change_90d 266.471622
# 36         USDC   quote.USD.percent_change_1h   0.003899
# 37         USDC  quote.USD.percent_change_24h  -0.021139
# 38         USDC   quote.USD.percent_change_7d   0.004444
# 39         USDC  quote.USD.percent_change_30d  -0.011281
# 40         USDC  quote.USD.percent_change_60d  -0.016277
# 41         USDC  quote.USD.percent_change_90d  -0.004714
# 42      Cardano   quote.USD.percent_change_1h  -1.711693
# 43      Cardano  quote.USD.percent_change_24h  17.103022
# 44      Cardano   quote.USD.percent_change_7d  46.435030
# 45      Cardano  quote.USD.percent_change_30d  82.272854
# 46      Cardano  quote.USD.percent_change_60d 163.298623
# 47      Cardano  quote.USD.percent_change_90d 156.762458
# 48    Avalanche   quote.USD.percent_change_1h  -1.497961
# 49    Avalanche  quote.USD.percent_change_24h   9.540374
# 50    Avalanche   quote.USD.percent_change_7d  46.470062
# 51    Avalanche  quote.USD.percent_change_30d 129.940884
# 52    Avalanche  quote.USD.percent_change_60d 317.052320
# 53    Avalanche  quote.USD.percent_change_90d 305.260228
# 54     Dogecoin   quote.USD.percent_change_1h  -0.642014
# 55     Dogecoin  quote.USD.percent_change_24h   4.389901
# 56     Dogecoin   quote.USD.percent_change_7d  -1.845574
# 57     Dogecoin  quote.USD.percent_change_30d  27.488918
# 58     Dogecoin  quote.USD.percent_change_60d  60.345922
# 59     Dogecoin  quote.USD.percent_change_90d  53.673939
# 60     Polkadot   quote.USD.percent_change_1h  -1.012368
# 61     Polkadot  quote.USD.percent_change_24h   8.927414
# 62     Polkadot   quote.USD.percent_change_7d  22.540170
# 63     Polkadot  quote.USD.percent_change_30d  38.588694
# 64     Polkadot  quote.USD.percent_change_60d  98.393334
# 65     Polkadot  quote.USD.percent_change_90d  81.577652
# 66         TRON   quote.USD.percent_change_1h  -0.121615
# 67         TRON  quote.USD.percent_change_24h   1.239343
# 68         TRON   quote.USD.percent_change_7d  -0.697955
# 69         TRON  quote.USD.percent_change_30d  -1.920391
# 70         TRON  quote.USD.percent_change_60d  22.390689
# 71         TRON  quote.USD.percent_change_90d  24.428899
# 72      Polygon   quote.USD.percent_change_1h  -0.635342
# 73      Polygon  quote.USD.percent_change_24h   3.304139
# 74      Polygon   quote.USD.percent_change_7d   6.251342
# 75      Polygon  quote.USD.percent_change_30d  -1.968171
# 76      Polygon  quote.USD.percent_change_60d  68.842448
# 77      Polygon  quote.USD.percent_change_90d  66.481635
# 78    Chainlink   quote.USD.percent_change_1h  -0.079332
# 79    Chainlink  quote.USD.percent_change_24h   4.231905
# 80    Chainlink   quote.USD.percent_change_7d  -4.763538
# 81    Chainlink  quote.USD.percent_change_30d   0.000230
# 82    Chainlink  quote.USD.percent_change_60d 100.366100
# 83    Chainlink  quote.USD.percent_change_90d 136.747769
# 84      Toncoin   quote.USD.percent_change_1h  -1.059229
# 85      Toncoin  quote.USD.percent_change_24h   5.784335
# 86      Toncoin   quote.USD.percent_change_7d  -5.059444
# 87      Toncoin  quote.USD.percent_change_30d  -7.181369
# 88      Toncoin  quote.USD.percent_change_60d  12.819119
# 89      Toncoin  quote.USD.percent_change_90d  13.818900

# %%
# Replace the full column names with shorter labels
df7['percent_change'] =  df7['percent_change'].replace(['quote.USD.percent_change_1h', 'quote.USD.percent_change_24h','quote.USD.percent_change_7d','quote.USD.percent_change_30d','quote.USD.percent_change_60d','quote.USD.percent_change_90d'],['1h', '24h', '7d', '30d', '60d', '90d'])
df7
# Out:
#            name percent_change     values
# 0       Bitcoin             1h  -0.239513
# 1       Bitcoin            24h   4.581726
# 2       Bitcoin             7d  -2.848970
# 3       Bitcoin            30d  17.125177
# 4       Bitcoin            60d  58.787309
# 5       Bitcoin            90d  60.650723
# 6      Ethereum             1h   0.048346
# 7      Ethereum            24h   4.011278
# 8      Ethereum             7d   0.197985
# 9      Ethereum            30d   9.478336
# 10     Ethereum            60d  44.762857
# 11     Ethereum            90d  37.903580
# 12  Tether USDt             1h   0.007006
# 13  Tether USDt            24h   0.029298
# 14  Tether USDt             7d   0.008849
# 15  Tether USDt            30d  -0.001631
# 16  Tether USDt            60d   0.017401
# 17  Tether USDt            90d   0.012238
# 18          BNB             1h  -0.217930
# 19          BNB            24h   0.638528
# 20          BNB             7d   7.393062
# 21          BNB            30d   2.826459
# 22          BNB            60d  20.185621
# 23          BNB            90d  17.153621
# 24          XRP             1h  -0.230150
# 25          XRP            24h   2.216319
# 26          XRP             7d  -1.642567
# 27          XRP            30d  -5.926147
# 28          XRP            60d  27.769564
# 29          XRP            90d  25.150395
# 30       Solana             1h  -0.264444
# 31       Solana            24h   5.663806
# 32       Solana             7d  11.352401
# 33       Solana            30d  28.058764
# 34       Solana            60d 217.639917
# 35       Solana            90d 266.471622
# 36         USDC             1h   0.003899
# 37         USDC            24h  -0.021139
# 38         USDC             7d   0.004444
# 39         USDC            30d  -0.011281
# 40         USDC            60d  -0.016277
# 41         USDC            90d  -0.004714
# 42      Cardano             1h  -1.711693
# 43      Cardano            24h  17.103022
# 44      Cardano             7d  46.435030
# 45      Cardano            30d  82.272854
# 46      Cardano            60d 163.298623
# 47      Cardano            90d 156.762458
# 48    Avalanche             1h  -1.497961
# 49    Avalanche            24h   9.540374
# 50    Avalanche             7d  46.470062
# 51    Avalanche            30d 129.940884
# 52    Avalanche            60d 317.052320
# 53    Avalanche            90d 305.260228
# 54     Dogecoin             1h  -0.642014
# 55     Dogecoin            24h   4.389901
# 56     Dogecoin             7d  -1.845574
# 57     Dogecoin            30d  27.488918
# 58     Dogecoin            60d  60.345922
# 59     Dogecoin            90d  53.673939
# 60     Polkadot             1h  -1.012368
# 61     Polkadot            24h   8.927414
# 62     Polkadot             7d  22.540170
# 63     Polkadot            30d  38.588694
# 64     Polkadot            60d  98.393334
# 65     Polkadot            90d  81.577652
# 66         TRON             1h  -0.121615
# 67         TRON            24h   1.239343
# 68         TRON             7d  -0.697955
# 69         TRON            30d  -1.920391
# 70         TRON            60d  22.390689
# 71         TRON            90d  24.428899
# 72      Polygon             1h  -0.635342
# 73      Polygon            24h   3.304139
# 74      Polygon             7d   6.251342
# 75      Polygon            30d  -1.968171
# 76      Polygon            60d  68.842448
# 77      Polygon            90d  66.481635
# 78    Chainlink             1h  -0.079332
# 79    Chainlink            24h   4.231905
# 80    Chainlink             7d  -4.763538
# 81    Chainlink            30d   0.000230
# 82    Chainlink            60d 100.366100
# 83    Chainlink            90d 136.747769
# 84      Toncoin             1h  -1.059229
# 85      Toncoin            24h   5.784335
# 86      Toncoin             7d  -5.059444
# 87      Toncoin            30d  -7.181369
# 88      Toncoin            60d  12.819119
# 89      Toncoin            90d  13.818900

# %% [markdown]
# ### Visualization for Percent Change over time for the top 15 coins

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Create a categorical plot using seaborn
sns.catplot(x='percent_change', y='values', hue='name', data=df7, kind='point')

# %%
# Fill NaN values in the 'timestamp' column with the current time in UTC
df['timestamp'] = df['timestamp'].fillna(pd.to_datetime('now', utc=True))

# Display unique values in the 'timestamp' column with a maximum of 6 rows
pd.set_option('display.max_rows', 6)
print(df['timestamp'].unique())
# Out:
# <DatetimeArray>
# ['2023-12-14 03:28:26.227710+00:00']
# Length: 1, dtype: datetime64[ns, UTC]

# %%
# Display selected columns ('name', 'quote.USD.price', 'timestamp') of the DataFrame
print(df[['name','quote.USD.price','timestamp']])
# Out:
#            name  quote.USD.price                        timestamp
# 0       Bitcoin     42716.697607 2023-12-14 03:28:26.227710+00:00
# 1      Ethereum      2252.248683 2023-12-14 03:28:26.227710+00:00
# 2   Tether USDt         1.000312 2023-12-14 03:28:26.227710+00:00
# ..          ...              ...                              ...
# 12      Polygon         0.877084 2023-12-14 03:28:26.227710+00:00
# 13    Chainlink        14.711515 2023-12-14 03:28:26.227710+00:00
# 14      Toncoin         2.177462 2023-12-14 03:28:26.227710+00:00
#
# [15 rows x 3 columns]

# %%
# Create a new DataFrame 'df10' containing only rows where 'name' is 'Solana'
df10 = df[['name','quote.USD.price','timestamp']]
df10 = df10.query("name == 'Solana'")
df10
# Out:
#      name  quote.USD.price                        timestamp
# 5  Solana        69.902003 2023-12-14 03:28:26.227710+00:00

# %%
# Set the theme style to 'darkgrid' in seaborn
sns.set_theme(style="darkgrid")

# Create a line plot using seaborn with x-axis as 'timestamp' and y-axis as 'quote.USD.price'
sns.lineplot(x='timestamp', y='quote.USD.price', data = df10)
# Out:
# <Axes: xlabel='timestamp', ylabel='quote.USD.price'>

# %% [markdown]
# - Can't seem to make a chart for the price over time since df10 only displays a single timestamp

# %% [markdown]
# ### Checking for Cryptocurrencies that include the word 'gaming' in the 'tags' section

# %%
# Assuming df is your original DataFrame

# Fill NaN values in the 'tags' column with an empty string
df['tags'] = df['tags'].fillna('')

# Check if 'gaming' is present in the 'tags' column for each row
mask = df['tags'].astype(str).str.contains('gaming', case=False)

# Apply the mask to filter the DataFrame
filtered_df = df[mask]

# Display the resulting DataFrame
print(filtered_df)
# Out:
#         id             name symbol             slug  num_market_pairs  \
# 30   10603        Immutable    IMX      immutable-x               220
# 42    5690           Render   RNDR           render               256
# 57   28298             Beam   BEAM           onbeam                57
# ..     ...              ...    ...              ...               ...
# 959  14722           DOGAMÍ   DOGA           dogami                12
# 973   4710     Cere Network   CERE     cere-network                24
# 974   7590  Dvision Network    DVI  dvision-network                29
#
#                    date_added  \
# 30   2021-06-24T00:00:00.000Z
# 42   2020-06-11T00:00:00.000Z
# 57   2021-10-29T04:07:32.000Z
# ..                        ...
# 959  2021-11-17T16:30:19.000Z
# 973  2021-11-08T13:18:17.000Z
# 974  2020-11-04T00:00:00.000Z
#
#                                                   tags        max_supply  \
# 30   [collectibles-nfts, zero-knowledge-proofs, gam... 2000000000.000000
# 42   [art, media, vr-ar, ai-big-data, distributed-c...  536870912.000000
# 57   [gaming, ethereum-ecosystem, binance-chain, bi...               NaN
# ..                                                 ...               ...
# 959   [gaming, play-to-earn, animoca-brands-portfolio] 1000000000.000000
# 973  [ai-big-data, distributed-computing, gaming, s...               NaN
# 974  [collectibles-nfts, gaming, ethereum-ecosystem... 1000000000.000000
#
#      circulating_supply       total_supply  infinite_supply  platform  \
# 30    1288194242.490024  2000000000.000000            False       NaN
# 42     371908453.108796   530962614.978783            False       NaN
# 57   47217187700.667519 62955102600.000000            False       NaN
# ..                  ...                ...              ...       ...
# 959    344541403.883030  1000000000.000000            False       NaN
# 973   1585541573.790000 10000000000.000000            False       NaN
# 974    689096290.000000  1000000000.000000            False       NaN
#
#      cmc_rank  self_reported_circulating_supply  self_reported_market_cap  \
# 30         31                  570354831.000000         1153804045.722955
# 42         43                               NaN                       NaN
# 57         58                47217661375.327660         1175647844.619395
# ..        ...                               ...                       ...
# 959       960                               NaN                       NaN
# 973       974                 2672732048.710000           15054407.983300
# 974       975                  186724316.000000            2418728.559718
#
#      tvl_ratio              last_updated  quote.USD.price  \
# 30         NaN  2023-12-14T03:36:00.000Z         2.022958
# 42         NaN  2023-12-14T03:35:00.000Z         4.380154
# 57         NaN  2023-12-14T03:35:00.000Z         0.024898
# ..         ...                       ...              ...
# 959        NaN  2023-12-14T03:35:00.000Z         0.027293
# 973        NaN  2023-12-14T03:35:00.000Z         0.005633
# 974        NaN  2023-12-14T03:35:00.000Z         0.012953
#
#      quote.USD.volume_24h  quote.USD.volume_change_24h  \
# 30       184708678.858780                   -29.668600
# 42       190738774.035040                   -18.538400
# 57       138809086.330464                    49.936300
# ..                    ...                          ...
# 959         228890.889100                   206.288000
# 973         846840.242856                    -4.702700
# 974         669168.157192                   -34.004200
#
#      quote.USD.percent_change_1h  quote.USD.percent_change_24h  \
# 30                      0.117285                      0.755819
# 42                      0.330084                      8.155062
# 57                      4.881882                     24.703981
# ..                           ...                           ...
# 959                     0.158977                     -0.763934
# 973                    -0.158499                     -6.311855
# 974                    -1.632489                      1.206407
#
#      quote.USD.percent_change_7d  quote.USD.percent_change_30d  \
# 30                     44.532527                     69.013462
# 42                     20.214277                     93.829071
# 57                     59.109701                    211.021181
# ..                           ...                           ...
# 959                   -28.708633                     62.746654
# 973                    -2.216257                     73.363431
# 974                    16.714220                     16.101018
#
#      quote.USD.percent_change_60d  quote.USD.percent_change_90d  \
# 30                     280.456354                    301.483438
# 42                     150.404502                    185.127689
# 57                     405.782687                    405.782687
# ..                            ...                           ...
# 959                    283.772898                    264.975380
# 973                     86.558946                     81.572218
# 974                     27.166555                     33.799959
#
#      quote.USD.market_cap  quote.USD.market_cap_dominance  \
# 30      2605963249.326817                        0.162700
# 42      1629016424.820349                        0.101700
# 57      1175636050.841875                        0.073400
# ..                    ...                             ...
# 959        9403432.615848                        0.000000
# 973        8930708.088691                        0.000000
# 974        8926190.828938                        0.000600
#
#      quote.USD.fully_diluted_market_cap  quote.USD.tvl  \
# 30                    4045916622.460000            NaN
# 42                    2351577455.000000            NaN
# 57                    1567486159.280000            NaN
# ..                                  ...            ...
# 959                     27292605.500000            NaN
# 973                            0.000000            NaN
# 974                     12953473.930000            NaN
#
#        quote.USD.last_updated  platform.id platform.name platform.symbol  \
# 30   2023-12-14T03:36:00.000Z  1027.000000      Ethereum             ETH
# 42   2023-12-14T03:35:00.000Z  1027.000000      Ethereum             ETH
# 57   2023-12-14T03:35:00.000Z  1027.000000      Ethereum             ETH
# ..                        ...          ...           ...             ...
# 959  2023-12-14T03:35:00.000Z  1027.000000      Ethereum             ETH
# 973  2023-12-14T03:35:00.000Z  1027.000000      Ethereum             ETH
# 974  2023-12-14T03:35:00.000Z  1027.000000      Ethereum             ETH
#
#     platform.slug                      platform.token_address  \
# 30       ethereum  0xf57e7e7c23978c3caec3c3548e3d615c346e79ff
# 42       ethereum  0x6de037ef9ad2725eb40118bb1702ebb27e4aeb24
# 57       ethereum  0x62D0A8458eD7719FDAF978fe5929C6D342B0bFcE
# ..            ...                                         ...
# 959      ethereum  0x4dbe83285fc959011f65dc613aeea638f18d3b92
# 973      ethereum  0x2da719db753dfa10a62e140f436e1d67f2ddb0d6
# 974      ethereum  0x10633216e7e8281e33c86f02bf8e565a635d9770
#
#                            timestamp
# 30  2023-12-14 03:37:50.440487+00:00
# 42  2023-12-14 03:37:50.440487+00:00
# 57  2023-12-14 03:37:50.440487+00:00
# ..                               ...
# 959 2023-12-14 03:37:50.440487+00:00
# 973 2023-12-14 03:37:50.440487+00:00
# 974 2023-12-14 03:37:50.440487+00:00
#
# [108 rows x 37 columns]

# %%
# Define selected columns and their desired names
selected_columns = {
    'name': 'Name',
    'symbol': 'Symbol',
    'tags': 'Tags',
    'quote.USD.price': 'Price',
    'quote.USD.percent_change_24h': '24h',
    'quote.USD.percent_change_1h': '1h',
    'quote.USD.percent_change_7d': '7d',
    'quote.USD.percent_change_30d': '30d',
    'quote.USD.percent_change_60d': '60d',
    'quote.USD.percent_change_90d': '90d',
    'timestamp': 'Timestamp'
}

# Display DataFrame with renamed and additional columns
display(filtered_df[selected_columns.keys()].rename(columns=selected_columns))
# Out:
#                 Name Symbol  \
# 30         Immutable    IMX
# 42            Render   RNDR
# 57              Beam   BEAM
# ..               ...    ...
# 959           DOGAMÍ   DOGA
# 973     Cere Network   CERE
# 974  Dvision Network    DVI
#
#                                                   Tags    Price       24h  \
# 30   [collectibles-nfts, zero-knowledge-proofs, gam... 2.022958  0.755819
# 42   [art, media, vr-ar, ai-big-data, distributed-c... 4.380154  8.155062
# 57   [gaming, ethereum-ecosystem, binance-chain, bi... 0.024898 24.703981
# ..                                                 ...      ...       ...
# 959   [gaming, play-to-earn, animoca-brands-portfolio] 0.027293 -0.763934
# 973  [ai-big-data, distributed-computing, gaming, s... 0.005633 -6.311855
# 974  [collectibles-nfts, gaming, ethereum-ecosystem... 0.012953  1.206407
#
#            1h         7d        30d        60d        90d  \
# 30   0.117285  44.532527  69.013462 280.456354 301.483438
# 42   0.330084  20.214277  93.829071 150.404502 185.127689
# 57   4.881882  59.109701 211.021181 405.782687 405.782687
# ..        ...        ...        ...        ...        ...
# 959  0.158977 -28.708633  62.746654 283.772898 264.975380
# 973 -0.158499  -2.216257  73.363431  86.558946  81.572218
# 974 -1.632489  16.714220  16.101018  27.166555  33.799959
#
#                            Timestamp
# 30  2023-12-14 03:37:50.440487+00:00
# 42  2023-12-14 03:37:50.440487+00:00
# 57  2023-12-14 03:37:50.440487+00:00
# ..                               ...
# 959 2023-12-14 03:37:50.440487+00:00
# 973 2023-12-14 03:37:50.440487+00:00
# 974 2023-12-14 03:37:50.440487+00:00
#
# [108 rows x 11 columns]

# %% [markdown]
# ### Top 10 gaming coins percent change in 90 days
#
# Charting the top 10 gaming coins in a bar chart to see percent change over 90 day period

# %%
import matplotlib.pyplot as plt

# Sort the DataFrame by a relevant column (e.g., 'cmc_rank') in ascending order
filtered_df = filtered_df.sort_values(by='cmc_rank')

# Select the top 10 rows
top_10_df = filtered_df.head(10)

# Bar chart for price comparison with a dark blue shade
plt.figure(figsize=(10, 6))
plt.bar(top_10_df['name'], top_10_df['quote.USD.percent_change_90d'], color=plt.cm.Blues(0.5)) 
plt.title('Cryptocurrency Percent Change 90d (Top 10 Coins)')
plt.xlabel('Cryptocurrency')
plt.ylabel('Percent Change (%)')
plt.xticks(rotation=45, ha='right')
plt.show()

# %% [markdown]
# Percent change for top 10 gaming coins over different time intervals

# %%
import matplotlib.pyplot as plt

# Sort the DataFrame by a relevant column (e.g., 'cmc_rank') in ascending order
filtered_df = filtered_df.sort_values(by='cmc_rank')

# Select the top 10 rows
top_10_df = filtered_df.head(10)

# Define the time intervals and corresponding labels
time_intervals = ['quote.USD.percent_change_1h', 'quote.USD.percent_change_24h',
                   'quote.USD.percent_change_7d', 'quote.USD.percent_change_30d',
                   'quote.USD.percent_change_60d', 'quote.USD.percent_change_90d']
time_labels = ['1h', '24h', '7d', '30d', '60d', '90d']

# Renamed names
renamed_names = {'Immutable': 'IMX', 'Render': 'RNDR', 'The Sandbox': 'SAND',
                 'Axie Infinity': 'AXS', 'Beam': 'BEAM', 'Decentraland': 'MANA',
                 'Gala': 'GALA', 'ApeCoin': 'APE', 'Illuvium' : 'ILV'}

# Set up the plot
plt.figure(figsize=(12, 8))

# Iterate through each cryptocurrency and plot a line for each time interval
for index, row in top_10_df.iterrows():
    plt.plot(time_labels, row[time_intervals], label=renamed_names.get(row['name'], row['name']), marker='o')

# Set labels and title
plt.title('Cryptocurrency Percent Change Over Different Time Intervals (Top 10 Coins)')
plt.xlabel('Time Intervals')
plt.ylabel('Percent Change (%)')

# Rotate x-axis labels for better readability
plt.xticks(rotation=45, ha='right')

# Add legend
plt.legend()

# Show the plot
plt.show()

# %% [markdown]
# ### Top 10 gaming coins based on 24h volume change

# %% [markdown]
# By analyzing this chart, we can look to see which coins are gaining attention and shift our focus towards these.

# %%
# Fill NaN values in the 'tags' column with an empty string
df['tags'] = df['tags'].fillna('')

# Check if 'gaming' is present in the 'tags' column for each row
mask = df['tags'].astype(str).str.contains('gaming', case=False)

# Apply the mask to filter the DataFrame
filtered_df = df[mask]

# Sort the filtered DataFrame by volume change and select the top 10 coins
top_gaming_coins = filtered_df.nlargest(10, 'quote.USD.volume_change_24h')

# Print the names of the top 10 gaming coins
print("Top 10 Gaming Coins with Highest 24h Volume Change:")
print(top_gaming_coins[['name', 'quote.USD.volume_change_24h']])
# Out:
# Top 10 Gaming Coins with Highest 24h Volume Change:
#                    name  quote.USD.volume_change_24h
# 347  Guild of Guardians                   715.295200
# 785            Volt Inu                   332.863400
# 329               Ultra                   276.522000
# ..                  ...                          ...
# 517              Biswap                   119.638300
# 906             PlayZap                   109.484300
# 672              Voxies                   103.416600
#
# [10 rows x 2 columns]

# %%
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors

# Sort the DataFrame by volume change and select the top 10 coins
top_volume_change_gaming_coins = top_volume_change_gaming_coins.sort_values(by='quote.USD.volume_change_24h', ascending=False)

# Set up a colormap and normalize the values
colormap = plt.cm.Greens
normalize = mcolors.Normalize(vmin=top_volume_change_gaming_coins['quote.USD.volume_change_24h'].min(),
                              vmax=top_volume_change_gaming_coins['quote.USD.volume_change_24h'].max())

# Create a bar chart with varying shades of green
plt.figure(figsize=(10, 6))
bars = plt.bar(top_volume_change_gaming_coins['name'],
               top_volume_change_gaming_coins['quote.USD.volume_change_24h'],
               color=colormap(normalize(top_volume_change_gaming_coins['quote.USD.volume_change_24h'])))

# Add a colorbar for reference
cbar = plt.colorbar(plt.cm.ScalarMappable(norm=normalize, cmap=colormap), ax=plt.gca())
cbar.set_label('Volume Change (USD)')

plt.title('Top 10 Gaming Coins by 24h Volume Change')
plt.xlabel('Cryptocurrency')
plt.ylabel('Volume Change (USD)')
plt.xticks(rotation=45, ha='right')
plt.show()

# %% [markdown]
# ### Making The Charts Interactive
#
# *Please note, you may not actually be able to interact with the chart on your end. This portion is only to display the code used to make the chart interactive*

# %%
pip install plotly
# Out:
# Requirement already satisfied: plotly in c:\users\jordan\anaconda3\lib\site-packages (5.9.0)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\jordan\anaconda3\lib\site-packages (from plotly) (8.2.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import plotly.express as px

# Sort the DataFrame by a relevant column (e.g., 'cmc_rank') in ascending order
filtered_df = filtered_df.sort_values(by='cmc_rank')

# Select the top 10 rows
top_10_df = filtered_df.head(10)

# Create a DataFrame with the necessary columns for the top 10 coins
plot_df = top_10_df[['name'] + time_intervals]

# Melt the DataFrame to have 'name' as the identifier variable
plot_df_melted = plot_df.melt(id_vars='name', var_name='Time Interval', value_name='Value')

# Rename the cryptocurrency names
plot_df_melted['name'] = plot_df_melted['name'].replace(renamed_names)

# Map the time intervals to the corresponding labels
plot_df_melted['Time Interval'] = plot_df_melted['Time Interval'].map(dict(zip(time_intervals, time_labels)))

# Create an interactive line chart with hover information for percent change
fig = px.line(plot_df_melted, x='Time Interval', y='Value', color='name', markers=True,
              labels={'Value': 'Percent Change (%)'},
              title='Top 10 Gaming Cryptocurrency Percent Change Over Time',
              template='plotly_dark', line_shape='linear', hover_data={'Value': ':,.2f'})

# Show the plot
fig.show()
# Out:
# <div>                            <div id="6795c84d-7881-45a1-8e6c-cfbf3fa079bf" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6795c84d-7881-45a1-8e6c-cfbf3fa079bf")) {                    Plotly.newPlot(                        "6795c84d-7881-45a1-8e6c-cfbf3fa079bf",                        [{"hovertemplate":"name=IMX<br>Time Interval=%{x}<br>Percent Change (%)=%{y:,.2f}<extra></extra>","legendgroup":"IMX","line":{"color":"#636efa","dash":"solid","shape":"linear"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"IMX","orientation":"v","showlegend":true,"x":["1h","24h","7d","30d","60d","90d"],"xaxis":"x","y":[0.11728498,0.75581911,44.53252671,69.01346166,280.4563539,301.48343783],"yaxis":"y","type":"scatter"},{"hovertemplate":"name=RNDR<br>Time Interval=%{x}<br>Percent Change (%)=%{y:,.2f}<extra></extra>","legendgroup":"RNDR","line":{"color":"#EF553B","dash":"solid","shape":"linear"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"RNDR","orientation":"v","showlegend":true,"x":["1h","24h","7d","30d","60d","90d"],"xaxis":"x","y":[0.33008352,8.15506211,20.2142771,93.82907065,150.40450195,185.12768927],"yaxis":"y","type":"scatter"},{"hovertemplate":"name=BEAM<br>Time Interval=%{x}<br>Percent Change (%)=%{y:,.2f}<extra></extra>","legendgroup":"BEAM","line":{"color":"#00cc96","dash":"solid","shape":"linear"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"BEAM","orientation":"v","showlegend":true,"x":["1h","24h","7d","30d","60d","90d"],"xaxis":"x","y":[4.88188202,24.70398135,59.1097008,211.02118144,405.78268742,405.78268742],"yaxis":"y","type":"scatter"},{"hovertemplate":"name=SAND<br>Time Interval=%{x}<br>Percent Change (%)=%{y:,.2f}<extra></extra>","legendgroup":"SAND","line":{"color":"#ab63fa","dash":"solid","shape":"linear"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"SAND","orientation":"v","showlegend":true,"x":["1h","24h","7d","30d","60d","90d"],"xaxis":"x","y":[-0.35147278,5.24483738,14.49804586,16.54431066,76.33896298,70.97286634],"yaxis":"y","type":"scatter"},{"hovertemplate":"name=AXS<br>Time Interval=%{x}<br>Percent Change (%)=%{y:,.2f}<extra></extra>","legendgroup":"AXS","line":{"color":"#FFA15A","dash":"solid","shape":"linear"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"AXS","orientation":"v","showlegend":true,"x":["1h","24h","7d","30d","60d","90d"],"xaxis":"x","y":[-0.1661433,3.84409327,1.78967502,16.86866885,66.97773413,49.66739003],"yaxis":"y","type":"scatter"},{"hovertemplate":"name=MANA<br>Time Interval=%{x}<br>Percent Change (%)=%{y:,.2f}<extra></extra>","legendgroup":"MANA","line":{"color":"#19d3f3","dash":"solid","shape":"linear"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"MANA","orientation":"v","showlegend":true,"x":["1h","24h","7d","30d","60d","90d"],"xaxis":"x","y":[0.07801085,5.03235049,3.91654481,12.48851483,74.0698449,69.31997535],"yaxis":"y","type":"scatter"},{"hovertemplate":"name=GALA<br>Time Interval=%{x}<br>Percent Change (%)=%{y:,.2f}<extra></extra>","legendgroup":"GALA","line":{"color":"#FF6692","dash":"solid","shape":"linear"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"GALA","orientation":"v","showlegend":true,"x":["1h","24h","7d","30d","60d","90d"],"xaxis":"x","y":[-0.29971246,6.53947436,9.70654265,42.80209254,132.81861197,119.46016179],"yaxis":"y","type":"scatter"},{"hovertemplate":"name=APE<br>Time Interval=%{x}<br>Percent Change (%)=%{y:,.2f}<extra></extra>","legendgroup":"APE","line":{"color":"#B6E880","dash":"solid","shape":"linear"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"APE","orientation":"v","showlegend":true,"x":["1h","24h","7d","30d","60d","90d"],"xaxis":"x","y":[-0.60313153,11.84179772,10.16682228,22.20177913,66.87779231,60.7247258 ...

# %%
import plotly.express as px

# Fill NaN values in the 'tags' column with an empty string
df['tags'] = df['tags'].fillna('')

# Check if 'gaming' is present in the 'tags' column for each row
mask = df['tags'].astype(str).str.contains('gaming', case=False)

# Apply the mask to filter the DataFrame
filtered_df = df[mask]

# Sort the filtered DataFrame by volume change and select the top 10 coins
top_volume_change_gaming_coins = filtered_df.nlargest(10, 'quote.USD.volume_change_24h')

# Create an interactive bar chart for the top 10 gaming coins by volume change
fig_volume_change_gaming = px.bar(top_volume_change_gaming_coins, x='name', y='quote.USD.volume_change_24h',
                                   title='Top 10 Gaming Coins by 24h Volume Change',
                                   labels={'quote.USD.volume_change_24h': 'Volume Change (USD)'},
                                   color='name')
fig_volume_change_gaming.update_layout(xaxis_title='Cryptocurrency', yaxis_title='Volume Change (USD)')

# Show the interactive chart for gaming coins
fig_volume_change_gaming.show()
# Out:
# <div>                            <div id="a5ca768c-490e-42f6-964b-83c523e5ac2f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a5ca768c-490e-42f6-964b-83c523e5ac2f")) {                    Plotly.newPlot(                        "a5ca768c-490e-42f6-964b-83c523e5ac2f",                        [{"alignmentgroup":"True","hovertemplate":"name=%{x}<br>Volume Change (USD)=%{y}<extra></extra>","legendgroup":"Guild of Guardians","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Guild of Guardians","offsetgroup":"Guild of Guardians","orientation":"v","showlegend":true,"textposition":"auto","x":["Guild of Guardians"],"xaxis":"x","y":[715.2952],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"name=%{x}<br>Volume Change (USD)=%{y}<extra></extra>","legendgroup":"Volt Inu","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Volt Inu","offsetgroup":"Volt Inu","orientation":"v","showlegend":true,"textposition":"auto","x":["Volt Inu"],"xaxis":"x","y":[332.8634],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"name=%{x}<br>Volume Change (USD)=%{y}<extra></extra>","legendgroup":"Ultra","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Ultra","offsetgroup":"Ultra","orientation":"v","showlegend":true,"textposition":"auto","x":["Ultra"],"xaxis":"x","y":[276.522],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"name=%{x}<br>Volume Change (USD)=%{y}<extra></extra>","legendgroup":"GuildFi","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"GuildFi","offsetgroup":"GuildFi","orientation":"v","showlegend":true,"textposition":"auto","x":["GuildFi"],"xaxis":"x","y":[223.2279],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"name=%{x}<br>Volume Change (USD)=%{y}<extra></extra>","legendgroup":"DOGAM\u00cd","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"DOGAM\u00cd","offsetgroup":"DOGAM\u00cd","orientation":"v","showlegend":true,"textposition":"auto","x":["DOGAM\u00cd"],"xaxis":"x","y":[206.288],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"name=%{x}<br>Volume Change (USD)=%{y}<extra></extra>","legendgroup":"Hoge Finance","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Hoge Finance","offsetgroup":"Hoge Finance","orientation":"v","showlegend":true,"textposition":"auto","x":["Hoge Finance"],"xaxis":"x","y":[139.1008],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"name=%{x}<br>Volume Change (USD)=%{y}<extra></extra>","legendgroup":"Matrix AI Network","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Matrix AI Network","offsetgroup":"Matrix AI Network","orientation":"v","showlegend":true,"textposition":"auto","x":["Matrix AI Network"],"xaxis":"x","y":[130.6887],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"name=%{x}<br>Volume Change (USD)=%{y}<extra></extra>","legendgroup":"Biswap","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"Biswap","offsetgroup":"Biswap","orientation":"v","showlegend":true,"textposition":"auto","x":["Biswap"],"xaxis":"x","y":[119.6383],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"name=%{x}<br>Volume Change (USD)=%{y}<extra></extra>","legendgroup":"PlayZap","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"PlayZap","offsetgroup":"PlayZap","orientation":"v","showlegend":true,"textposition":"auto","x":["PlayZap"],"xaxis":"x","y":[109.4843],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"name=%{x}<br>Volume Change (USD)=%{y}<extra></extra>","legendgroup":"Voxies","marker":{"color":"#FECB52","pattern":{"shape":""}},"name":"Voxies","offsetgroup":"Voxies","orientation":"v","showlegend":true,"textposition":"auto","x":["Voxies"],"xaxis":"x","y": ...
